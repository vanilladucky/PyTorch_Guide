# %% [markdown]
# <p style="text-align: center; font-size:50px;">Implementing Transformers</p>

# %% [markdown]
# #### In this notebook, I will show you how transformers can be implemented.
# #### PyTorch is a fantastic framework that supports transformers with just a few lines of code.
# #### To run data through the models to show that it works, we wil be using the wikitext that is available on Hugging Face but do not expect superb results from it.
# #### I can tell you from personal experience that with free cloud notebooks online utilizing strong GPUs and large amount of memory, they are not sufficient enough to build a language model that would converse like a human being.
# #### Therefore, the focus for this notebook will purely be about the implementation of Transformers.
# #### I will closely follow the architecture shown in the "Attention is all you need" paper and the official guide about transformers on PyTorch's website.

# %% [markdown]
# # Credit
# * https://arxiv.org/pdf/1706.03762.pdf
# * https://pytorch.org/tutorials/beginner/transformer_tutorial.html
# * https://towardsdatascience.com/how-to-code-the-transformer-in-pytorch-24db27c8f9ec

# %%
import torch 
import torch.nn as nn 
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
from torch.nn import functional as F
import math
import torchinfo 
from torchinfo import summary
from tqdm import tqdm
import gc
import datasets

# %% [markdown]
# # Loading Data

# %%
import datasets
from datasets import load_dataset
from torchtext.datasets import WikiText2

dataset = datasets.load_dataset('wikitext', 'wikitext-2-v1')
# Out:
# Downloading builder script:   0%|          | 0.00/8.48k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/6.84k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/9.25k [00:00<?, ?B/s]
# Downloading and preparing dataset wikitext/wikitext-2-v1 to /root/.cache/huggingface/datasets/wikitext/wikitext-2-v1/1.0.0/a241db52902eaf2c6aa732210bead40c090019a499ceb13bcbfa3f8ab646a126...
# Downloading data:   0%|          | 0.00/4.48M [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/4358 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/36718 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/3760 [00:00<?, ? examples/s]
# Dataset wikitext downloaded and prepared to /root/.cache/huggingface/datasets/wikitext/wikitext-2-v1/1.0.0/a241db52902eaf2c6aa732210bead40c090019a499ceb13bcbfa3f8ab646a126. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
device = torch.device('cuda') # Setting up the device 

print(device)

# Tokenizing each word 
tokenizer = get_tokenizer('basic_english')
# Building a vocab 
vocab = build_vocab_from_iterator(map(tokenizer, dataset['train']['text']), min_freq=2, specials=['<unk>', '<eos>'])
vocab.set_default_index(vocab['<unk>']) 

print(f"The length of the vocab is {len(vocab)}")                         
print(vocab.get_itos()[:10])
# Out:
# cuda
# The length of the vocab is 28783
# ['<unk>', '<eos>', 'the', ',', '.', 'of', 'and', 'in', 'to', 'a']

# %%
# Splitting the data 

encoded_data = [torch.tensor(vocab(tokenizer(item)), dtype=torch.long) for item in dataset['train']['text'] if len(item) > 0]
n = int(0.8*len(encoded_data)) # first 80% will be train, rest val
train_data = encoded_data[:n]
val_data = encoded_data[n:]

del encoded_data
gc.collect()

# train_data and val_data will have encoded data (numerical representation of our text inputs)
# Out:
# 93

# %%
flat_train_data = torch.cat(train_data)
flat_val_data = torch.cat(val_data)

del train_data
del val_data
gc.collect()
# Out:
# 0

# %%
# Batching 
# We have to come up with a function to be able to appropriately batch our data

batch_size = 64 # The batch size our model will process in parallel 
block_size = 128 # Maximum length that feeds into our model 
number_of_batches_train = len(flat_train_data) // (batch_size*block_size) # Total number of batches in the training set
number_of_batches_val = len(flat_val_data) // (batch_size*block_size) # Total number of batches in the validation set 

def get_batch(split, batch_idx):
  data = flat_train_data if split == 'train' else flat_val_data  
  X = torch.stack([data[batch_idx*batch_size*block_size + i*block_size:batch_idx*batch_size*block_size + i*block_size+block_size] for i in range(batch_size)])
  y = torch.stack([data[batch_idx*batch_size*block_size + i*block_size+1:batch_idx*batch_size*block_size + i*block_size+block_size+1] for i in range(batch_size)])
  return X.to(device), y.to(device)

X, y = get_batch('train', 197)
print(f"This is what X looks like:\n{X}\n")
print(f"This is what y looks like:\n{y}")
print("")
print(f"We have {number_of_batches_train} number of training batches\n")
print(f"We have {number_of_batches_val} number of validation batches")
# Out:
# This is what X looks like:
# tensor([[   23,   169,     8,  ...,    20,    69,   114],
#         [    5,    37,  1951,  ...,    10,    10,    10],
#         [    2,   209,   113,  ...,     6, 12079,    10],
#         ...,
#         [   11,   409,   522,  ...,   302,  1456,  1757],
#         [ 2083,   130,  5603,  ...,  3195,     4,    91],
#         [   37,  1144,     6,  ...,  2417,  3256,     5]], device='cuda:0')
#
# This is what y looks like:
# tensor([[  169,     8,    71,  ...,    69,   114,     5],
#         [   37,  1951,     3,  ...,    10,    10,     2],
#         [  209,   113,    34,  ..., 12079,    10,    10],
#         ...,
#         [  409,   522,     8,  ...,  1456,  1757,  2083],
#         [  130,  5603,    15,  ...,     4,    91,    37],
#         [ 1144,     6,    28,  ...,  3256,     5,  1416]], device='cuda:0')
#
# We have 199 number of training batches
#
# We have 51 number of validation batches

# %% [markdown]
# # Building model using PyTorch's nn.Transformer module.

# %% [markdown]
# #### Firstly, we will build our transformer using the nn.Transformer module.

# %% [markdown]
# #### We will first build the positional encoder.
# #### Since Transformers do not take in input sequentially unlike RNNs, we would have to relay the information about each token's positioning relative to the whole input.
# #### The research paper states that it simply utilized sin and cos functions to relay this information.

# %%
class PositionalEncoding(nn.Module):

    def __init__(self, d_model: int, max_len: int = 5000):
        super().__init__()

        position = torch.arange(max_len).unsqueeze(1) # positioning vector 
        sin_div_term = 10000 ** (torch.arange(0, d_model, 2) / d_model)
        cos_div_term = 10000 ** (torch.arange(1, d_model, 2) / d_model)
        pe = torch.zeros(1, max_len, d_model)
        pe[0, :, 0::2] = torch.sin(position / sin_div_term)
        pe[0, :, 1::2] = torch.cos(position / cos_div_term)
        self.register_buffer('pe', pe)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """
        Arguments:
            x: Tensor, shape [batch_size, seq_len, embedding_dim]
        """
        batch_size, seq_len, embed_dim = x.size()

        x = x + self.pe[:, :seq_len, :] # only until the actual sequence length 

        return x.to(device)

print("Testing to ensure positional encoder works\n")
eg = torch.randn(64, 128, 300)

try:    
    pe = PositionalEncoding(300)
    out = pe(eg)
    print(f"The shape of the output is {out.shape}")
except:
    print("Error!")
# Out:
# Testing to ensure positional encoder works
#
# The shape of the output is torch.Size([64, 128, 300])

# %% [markdown]
# #### Ok!
# #### Seems like our positional encoder is working properly.
# #### We can now proceed on to utilize the transformer module from PyTorch.

# %%
vocab_size = len(vocab)
d_model = 300 
n_head = 3
n_layers = 7
d_hidden = 2000
dropout = 0.4

def generate_square_subsequent_mask(sz: int) -> torch.Tensor:
    """Generates an upper-triangular matrix of ``-inf``, with zeros on ``diag``."""
    return torch.triu(torch.ones(sz, sz) * float('-inf'), diagonal=1).to(device)

class Transformer(nn.Module):

    def __init__(self, vocab_size:int, d_model:int, n_head:int, n_layers:int, d_hidden:int, dropout:float = 0.1):
        super().__init__()
        self.positional_encoder = PositionalEncoding(d_model, max_len = 200) 
        self.embedding = nn.Embedding(vocab_size, d_model)

        # Encoder 
        encoder_layers = nn.TransformerEncoderLayer(d_model, n_head, d_hidden, dropout, batch_first=True)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, n_layers)

        # Decoder
        decoder_layers = nn.TransformerDecoderLayer(d_model, n_head, d_hidden, dropout, batch_first=True)
        self.transformer_decoder = nn.TransformerDecoder(decoder_layers, n_layers)

        self.out = nn.Linear(d_model, vocab_size)

        self.init_weights()

    def init_weights(self) -> None:
        initrange = 0.1
        self.embedding.weight.data.uniform_(-initrange, initrange)
        self.out.bias.data.zero_()
        self.out.weight.data.uniform_(-initrange, initrange)

    def forward(self, x, target, mask) -> torch.Tensor:
        x = self.embedding(x)
        x = self.positional_encoder(x)
        x = self.transformer_encoder(x)
        x = self.transformer_decoder(self.positional_encoder(self.embedding(target)), x, mask)
        x = self.out(x)

        logits = x.clone().detach()

        # Calculating loss 
        B, T, C = x.shape
        x = x.view(B*T, C)
        target = target.view(B*T)
        loss = nn.CrossEntropyLoss()(x, target)
        return logits, loss

mask = generate_square_subsequent_mask(block_size)
model = Transformer(vocab_size, d_model, n_head, n_layers, d_hidden, dropout).to(device)
summary(model)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                                            Param #
# ==========================================================================================
# Transformer                                                       --
# ├─PositionalEncoding: 1-1                                         --
# ├─Embedding: 1-2                                                  8,634,900
# ├─TransformerEncoder: 1-3                                         --
# │    └─ModuleList: 2-1                                            --
# │    │    └─TransformerEncoderLayer: 3-1                          1,564,700
# │    │    └─TransformerEncoderLayer: 3-2                          1,564,700
# │    │    └─TransformerEncoderLayer: 3-3                          1,564,700
# │    │    └─TransformerEncoderLayer: 3-4                          1,564,700
# │    │    └─TransformerEncoderLayer: 3-5                          1,564,700
# │    │    └─TransformerEncoderLayer: 3-6                          1,564,700
# │    │    └─TransformerEncoderLayer: 3-7                          1,564,700
# ├─TransformerDecoder: 1-4                                         --
# │    └─ModuleList: 2-2                                            --
# │    │    └─TransformerDecoderLayer: 3-8                          1,926,500
# │    │    └─TransformerDecoderLayer: 3-9                          1,926,500
# │    │    └─TransformerDecoderLayer: 3-10                         1,926,500
# │    │    └─TransformerDecoderLayer: 3-11                         1,926,500
# │    │    └─TransformerDecoderLayer: 3-12                         1,926,500
# │    │    └─TransformerDecoderLayer: 3-13                         1,926,500
# │    │    └─TransformerDecoderLayer: 3-14                         1,926,500
# ├─Linear: 1-5                                                     8,663,683
# ==========================================================================================
# Total params: 41,736,983
# Trainable params: 41,736,983
# Non-trainable params: 0
# ==========================================================================================

# %% [markdown]
# #### Before we come up with any training loop, it's good practice to observe whether our model is able to take in our input and output without any problems.
# #### Let's try out our model with the first batch of our data.

# %%
X, y = get_batch('train', 0)
try:
    out, loss = model(X, y, mask)
    print("Model working successfully")
except:
    print("Error occured!")
# Out:
# Model working successfully

# %% [markdown]
# #### Perfect!
# #### Seems like everything is working properly.
# #### Let's write up our training and validation loop now and watch the training progress.

# %%
for p in model.parameters(): # Ensuring model's parameters stay in a range to prevent explosion or vanishing
    if p.dim() > 1:
        nn.init.xavier_uniform_(p)

# %%
@torch.no_grad()
def validate():
    model.eval()
    validation_loss = 0 
    count = 0 
    mask = generate_square_subsequent_mask(block_size)
    for batch_idx in range(number_of_batches_val):
        X, y = get_batch('val', batch_idx)
        _, loss = model(X, y, mask)
        validation_loss += loss.item()
        count += 1
    return validation_loss / count

# %%
import warnings
warnings.filterwarnings("ignore")

epoch = 100
log_interval = 50
learning_rate = 0.01
eval_iters = 50

optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, eps=1e-9)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95)
train_loss = 0
count = 0
best_loss = float('inf')
mask = generate_square_subsequent_mask(block_size)

for epoch in range(epoch):
    print(f"====Epoch {epoch}====")
    for batch_idx in range(number_of_batches_train):

        # sample a batch of data
        X, y = get_batch('train', batch_idx)

        # Validating
        if (batch_idx+1) % eval_iters == 0:
            losses = validate()
            print(f"epoch: {epoch+1}, batch_idx: {batch_idx+1}, train loss: {train_loss/count:.4f}, val loss: {losses:.4f}, lr: {scheduler.get_last_lr()[0]:.6f}")
            if losses < best_loss:
                print("Saving better model")
                torch.save(model.state_dict(), './best_params.pt') # Saving best model parameters
                best_loss = losses
            print("\n")
            scheduler.step()

        model.train()
        # Training
        logits, loss = model(X, y, mask)
        train_loss += loss.item()
        optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()
        count += 1
# Out:
# ====Epoch 0====
# epoch: 1, batch_idx: 50, train loss: 7.6192, val loss: 8.0036, lr: 0.010000
# Saving better model
#
#
# epoch: 1, batch_idx: 100, train loss: 7.3791, val loss: 8.1459, lr: 0.009500
#
#
# epoch: 1, batch_idx: 150, train loss: 7.2881, val loss: 7.8042, lr: 0.009025
# Saving better model
#
#
# ====Epoch 1====
# epoch: 2, batch_idx: 50, train loss: 7.1818, val loss: 7.9196, lr: 0.008574
#
#
# epoch: 2, batch_idx: 100, train loss: 7.1396, val loss: 7.4546, lr: 0.008145
# Saving better model
#
#
# epoch: 2, batch_idx: 150, train loss: 7.1099, val loss: 7.4691, lr: 0.007738
#
#
# ====Epoch 2====
# epoch: 3, batch_idx: 50, train loss: 7.0723, val loss: 7.5743, lr: 0.007351
#
#
# epoch: 3, batch_idx: 100, train loss: 7.0599, val loss: 7.4409, lr: 0.006983
# Saving better model
#
#
# epoch: 3, batch_idx: 150, train loss: 7.0495, val loss: 7.3011, lr: 0.006634
# Saving better model
#
#
# ====Epoch 3====
# epoch: 4, batch_idx: 50, train loss: 7.0304, val loss: 7.3483, lr: 0.006302
#
#
# epoch: 4, batch_idx: 100, train loss: 7.0235, val loss: 7.2615, lr: 0.005987
# Saving better model
#
#
# epoch: 4, batch_idx: 150, train loss: 7.0164, val loss: 7.1948, lr: 0.005688
# Saving better model
#
#
# ====Epoch 4====
# epoch: 5, batch_idx: 50, train loss: 7.0041, val loss: 7.2612, lr: 0.005404
#
#
# epoch: 5, batch_idx: 100, train loss: 6.9991, val loss: 7.2392, lr: 0.005133
#
#
# epoch: 5, batch_idx: 150, train loss: 6.9940, val loss: 7.1631, lr: 0.004877
# Saving better model
#
#
# ====Epoch 5====
# epoch: 6, batch_idx: 50, train loss: 6.9856, val loss: 7.1948, lr: 0.004633
#
#
# epoch: 6, batch_idx: 100, train loss: 6.9813, val loss: 7.2545, lr: 0.004401
#
#
# epoch: 6, batch_idx: 150, train loss: 6.9773, val loss: 7.1633, lr: 0.004181
#
#
# ====Epoch 6====
# epoch: 7, batch_idx: 50, train loss: 6.9711, val loss: 7.1760, lr: 0.003972
#
#
# epoch: 7, batch_idx: 100, train loss: 6.9676, val loss: 7.2804, lr: 0.003774
#
#
# epoch: 7, batch_idx: 150, train loss: 6.9646, val loss: 7.1529, lr: 0.003585
# Saving better model
#
#
# ====Epoch 7====
# epoch: 8, batch_idx: 50, train loss: 6.9595, val loss: 7.1720, lr: 0.003406
#
#
# epoch: 8, batch_idx: 100, train loss: 6.9567, val loss: 7.2730, lr: 0.003235
#
#
# epoch: 8, batch_idx: 150, train loss: 6.9545, val loss: 7.1442, lr: 0.003074
# Saving better model
#
#
# ====Epoch 8====
# epoch: 9, batch_idx: 50, train loss: 6.9503, val loss: 7.1608, lr: 0.002920
#
#
# epoch: 9, batch_idx: 100, train loss: 6.9481, val loss: 7.2450, lr: 0.002774
#
#
# epoch: 9, batch_idx: 150, train loss: 6.9464, val loss: 7.1562, lr: 0.002635
#
#
# ====Epoch 9====
# epoch: 10, batch_idx: 50, train loss: 6.9431, val loss: 7.1455, lr: 0.002503
#
#
# epoch: 10, batch_idx: 100, train loss: 6.9414, val loss: 7.2120, lr: 0.002378
#
#
# epoch: 10, batch_idx: 150, train loss: 6.9400, val loss: 7.1789, lr: 0.002259
#
#
# ====Epoch 10====
# epoch: 11, batch_idx: 50, train loss: 6.9376, val loss: 7.1367, lr: 0.002146
# Saving better model
#
#
# epoch: 11, batch_idx: 100, train loss: 6.9364, val loss: 7.1808, lr: 0.002039
#
#
# epoch: 11, batch_idx: 150, train loss: 6.9352, val loss: 7.1889, lr: 0.001937
#
#
# ====Epoch 11====
# epoch: 12, batch_idx: 50, train loss: 6.9336, val loss: 7.1343, lr: 0.001840
# Saving better model
#
#
# epoch: 12, batch_idx: 100, train loss: 6.9328, val loss: 7.1565, lr: 0.001748
#
#
# epoch: 12, batch_idx: 150, train loss: 6.9318, val loss: 7.1849, lr: 0.001661
#
#
# ====Epoch 12====
# epoch: 13, batch_idx: 50, train loss: 6.9307, val loss: 7.1280, lr: 0.001578
# Saving better model
#
#
# epoch: 13, batch_idx: 100, train loss: 6.9301, val loss: 7.1417, lr: 0.001499
#
#
# epoch: 13, batch_idx: 150, train loss: 6.9293, val loss: 7.1727, lr: 0.001424
#
#
# ====Epoch 13====
# epoch: 14, batch_idx: 50, train loss: 6.9285, val loss: 7.1198, lr: 0.001353
# Saving better model
#
#
# epoch: 14, batch_idx: 100, train loss: 6.9280, val loss: 7.1312, lr: 0.001285
#
#
# epoch: 14, batch_idx: 150, train loss: 6.9274, val loss: 7.1564, lr: 0.001221
#
#
# ====Epoch 14====
# epoch: 15, batch_idx: 50, train loss: 6.9268, val loss: 7.1144, lr: 0.001160
# Saving better model
#
#
# epoch: 15, batch_idx: 100, train loss: 6.9264, val loss: 7.1243, lr: 0.001102
#
#
# epoch: 15, batch_idx: 150, train loss: 6.9259, val loss: 7.1442, lr: 0.001047
#
#
# ====Epoch 15====
# epoch: 16, batch_idx: 50, train loss: 6.9254, val loss: 7.1120, lr: 0.000994
# Saving better model
#
#
# epoch: 16, batch_idx: 100, train loss: 6.9249, val loss: 7.1201, lr: 0.000945
#
#
# epoch: 16, batch_idx: 150, train loss: 6.9245, val loss: 7.1376, lr: 0.000897
#
#
# ====Epoch 16====
# epoch: 17, batch_idx: 50, train loss: 6.9240, val loss: 7.1120, lr: 0.000853
#
#
# epoch: 17, batch_idx: 100, train loss: 6.9236, val loss: 7.1180, lr: 0.000810
#
#
# epoch: 17, batch_idx: 150, train loss: 6.9232, val loss: 7.1328, lr: 0.000769
#
#
# ====Epoch 17====
# epoch: 18, batch_idx: 50, train loss: 6.9228, val loss: 7.1127, lr: 0.000731
#
#
# epoch: 18, batch_idx: 100, train loss: 6.9224, val loss: 7.1169, lr: 0.000694
#
#
# epoch: 18, batch_idx: 150, train loss: 6.9220, val loss: 7.1298, lr: 0.000660
#
#
# ====Epoch 18====
# epoch: 19, batch_idx: 50, train loss: 6.9216, val loss: 7.1139, lr: 0.000627
#
#
# epoch: 19, batch_idx: 100, train loss: 6.9212, val loss: 7.1170, lr: 0.000595
#
#
# epoch: 19, batch_idx: 150, train loss: 6.9208, val loss: 7.1279, lr: 0.000566
#
#
# ====Epoch 19====
# epoch: 20, batch_idx: 50, train loss: 6.9204, val loss: 7.1147, lr: 0.000537
#
#
# epoch: 20, batch_idx: 100, train loss: 6.9201, val loss: 7.1173, lr: 0.000510
#
#
# epoch: 20, batch_idx: 150, train loss: 6.9197, val loss: 7.1265, lr: 0.000485
#
#
# ====Epoch 20====
# epoch: 21, batch_idx: 50, train loss: 6.9193, val loss: 7.1155, lr: 0.000461
#
#
# epoch: 21, batch_idx: 100, train loss: 6.9190, val loss: 7.1181, lr: 0.000438
#
#
# epoch: 21, batch_idx: 150, train loss: 6.9187, val loss: 7.1255, lr: 0.000416
#
#
# ====Epoch 21====
# epoch: 22, batch_idx: 50, train loss: 6.9183, val loss: 7.1162, lr: 0.000395
#
#
# epoch: 22, batch_idx: 100, train loss: 6.9180, val loss: 7.1193, lr: 0.000375
#
#
# epoch: 22, batch_idx: 150, train loss: 6.9176, val loss: 7.1250, lr: 0.000356
#
#
# ====Epoch 22====
# epoch: 23, batch_idx: 50, train loss: 6.9173, val loss: 7.1170, lr: 0.000339
#
#
# epoch: 23, batch_idx: 100, train loss: 6.9170, val loss: 7.1204, lr: 0.000322
#
#
# epoch: 23, batch_idx: 150, train loss: 6.9167, val loss: 7.1249, lr: 0.000306
#
#
# ====Epoch 23====
# epoch: 24, batch_idx: 50, train loss: 6.9164, val loss: 7.1178, lr: 0.000290
#
#
# epoch: 24, batch_idx: 100, train loss: 6.9161, val loss: 7.1213, lr: 0.000276
#
#
# epoch: 24, batch_idx: 150, train loss: 6.9158, val loss: 7.1250, lr: 0.000262
#
#
# ====Epoch 24====
# epoch: 25, batch_idx: 50, train loss: 6.9154, val loss: 7.1187, lr: 0.000249
#
#
# epoch: 25, batch_idx: 100, train loss: 6.9152, val loss: 7.1219, lr: 0.000236
#
#
# epoch: 25, batch_idx: 150, train loss: 6.9149, val loss: 7.1251, lr: 0.000225
#
#
# ====Epoch 25====
# epoch: 26, batch_idx: 50, train loss: 6.9146, val loss: 7.1197, lr: 0.000213
#
#
# epoch: 26, batch_idx: 100, train loss: 6.9143, val loss: 7.1226, lr: 0.000203
#
#
# epoch: 26, batch_idx: 150, train loss: 6.9140, val loss: 7.1253, lr: 0.000193
#
#
# ====Epoch 26====
# epoch: 27, batch_idx: 50, train loss: 6.9137, val loss: 7.1207, lr: 0.000183
#
#
# epoch: 27, batch_idx: 100, train loss: 6.9135, val loss: 7.1233, lr: 0.000174
#
#
# epoch: 27, batch_idx: 150, train loss: 6.9132, val loss: 7.1256, lr: 0.000165
#
#
# ====Epoch 27====
# epoch: 28, batch_idx: 50, train loss: 6.9129, val loss: 7.1217, lr: 0.000157
#
#
# epoch: 28, batch_idx: 100, train loss: 6.9127, val loss: 7.1240, lr: 0.000149
#
#
# epoch: 28, batch_idx: 150, train loss: 6.9125, val loss: 7.1259, lr: 0.000142
#
#
# ====Epoch 28====
# epoch: 29, batch_idx: 50, train loss: 6.9122, val loss: 7.1226, lr: 0.000135
#
#
# epoch: 29, batch_idx: 100, train loss: 6.9120, val loss: 7.1247, lr: 0.000128
#
#
# epoch: 29, batch_idx: 150, train loss: 6.9117, val loss: 7.1262, lr: 0.000121
#
#
# ====Epoch 29====
# epoch: 30, batch_idx: 50, train loss: 6.9115, val loss: 7.1235, lr: 0.000115
#
#
# epoch: 30, batch_idx: 100, train loss: 6.9113, val loss: 7.1254, lr: 0.000110
#
#
# epoch: 30, batch_idx: 150, train loss: 6.9110, val loss: 7.1267, lr: 0.000104
#
#
# ====Epoch 30====
# epoch: 31, batch_idx: 50, train loss: 6.9108, val loss: 7.1243, lr: 0.000099
#
#
# epoch: 31, batch_idx: 100, train loss: 6.9106, val loss: 7.1259, lr: 0.000094
#
#
# epoch: 31, batch_idx: 150, train loss: 6.9103, val loss: 7.1271, lr: 0.000089
#
#
# ====Epoch 31====
# epoch: 32, batch_idx: 50, train loss: 6.9101, val loss: 7.1251, lr: 0.000085
#
#
# epoch: 32, batch_idx: 100, train loss: 6.9099, val loss: 7.1264, lr: 0.000081
#
#
# epoch: 32, batch_idx: 150, train loss: 6.9097, val loss: 7.1275, lr: 0.000077
#
#
# ====Epoch 32====
# epoch: 33, batch_idx: 50, train loss: 6.9095, val loss: 7.1258, lr: 0.000073
#
#
# epoch: 33, batch_idx: 100, train loss: 6.9093, val loss: 7.1269, lr: 0.000069
#
#
# epoch: 33, batch_idx: 150, train loss: 6.9091, val loss: 7.1279, lr: 0.000066
#
#
# ====Epoch 33====
# epoch: 34, batch_idx: 50, train loss: 6.9089, val loss: 7.1263, lr: 0.000062
#
#
# epoch: 34, batch_idx: 100, train loss: 6.9087, val loss: 7.1273, lr: 0.000059
#
#
# epoch: 34, batch_idx: 150, train loss: 6.9085, val loss: 7.1283, lr: 0.000056
#
#
# ====Epoch 34====
# epoch: 35, batch_idx: 50, train loss: 6.9083, val loss: 7.1268, lr: 0.000053
#
#
# epoch: 35, batch_idx: 100, train loss: 6.9082, val loss: 7.1276, lr: 0.000051
#
#
# epoch: 35, batch_idx: 150, train loss: 6.9080, val loss: 7.1286, lr: 0.000048
#
#
# ====Epoch 35====
# epoch: 36, batch_idx: 50, train loss: 6.9078, val loss: 7.1272, lr: 0.000046
#
#
# epoch: 36, batch_idx: 100, train loss: 6.9076, val loss: 7.1279, lr: 0.000044
#
#
# epoch: 36, batch_idx: 150, train loss: 6.9074, val loss: 7.1289, lr: 0.000041
#
#
# ====Epoch 36====
# epoch: 37, batch_idx: 50, train loss: 6.9073, val loss: 7.1276, lr: 0.000039
#
#
# epoch: 37, batch_idx: 100, train loss: 6.9071, val loss: 7.1282, lr: 0.000037

# %% [markdown]
# #### The losses definitely seem to decrease but only until a point such as around 7.1 for the validation loss.
# #### Our model's architecture definitely is not complex enough with only around 40 million parameters.
# #### However I hope you got to see how we can implement transformers using PyTorch and it's accompanying nn.Transformer module.
