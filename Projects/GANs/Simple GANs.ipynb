# %% [markdown]
# <p style="text-align: center; font-size:50px;">Simple GANs using PyTorch</p>

# %% [markdown]
# #### With Generative AI being hyped up these days, I think it's worth to take a look at what a GAN is and provide a simple example about it.
# #### I have made another notebook talking about a more complicated version of this, so if you would like to begin with a simpler version, do follow along this notebook!

# %% [markdown]
# ##### This notebook was inspired by this [tutorial](https://jovian.com/learn/deep-learning-with-pytorch-zero-to-gans/lesson/lesson-6-image-generation-using-gans?notebook=aakashns/06-mnist-gan) and you can find more of these tutorials there.

# %% [markdown]
# #### You might be wondering what a GAN is.
# #### Generative modeling is an **unsupervised** learning task in which machine learning that involves automatically discovering and learning the regularities or patterns in input data in such a way that the model can be used to generate or output new examples that plausibly could have been drawn from the original dataset.
# #### Basically, it will learn patterns and probability distributions from the training data, and closely emulate them.

# %% [markdown]
# #### The general overview is that there are 2 neural networks: a Generator and a Discriminator.
# #### The generator generates a 'fake' sample given a random vector/atrix, and the discriminator attempts to detect whether a given sample is 'real' or 'fake'.
# #### Training happens in tandem, which means we take turns training the generator and discriminator.
# #### This way, both the generator and discriminator both gets better at performing their respective jobs.
# #### However, GANs are notorious for being difficult to train, as they can be extremely sensitive to hyperparameters, activation functions and regularization.
# #### In this tutorial, we will built a GAN to generate images of handwritten digits similar to those from the MNIST database.

# %% [markdown]
# <p style="text-align: center; font-size:30px;">Load the Data</p>

# %% [markdown]
# #### Let us first load the data using the MNIST helper class from torchvision.dataset.

# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST

mnist = MNIST(root='../data/', 
              train=True, 
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))

# %% [markdown]
# #### Let's take a look at a single data.

# %%
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

import matplotlib.pyplot as plt
# %matplotlib inline

img, label = mnist[0]

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)
# Out:
# Label: 5

# %% [markdown]
# #### Ok, seems like our data was downloaded with any errors.
# #### Let's now create a dataloader to load images in batches.
# #### This can be done with the DataLoader from torch.utils.data

# %%
from torch.utils.data import DataLoader

batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

for img_batch, label_batch in data_loader:
    print('first batch')
    print(f"{img_batch.shape} -> [batch_size, color channel, dimension, dimension]")
    plt.imshow(img_batch[0][0], cmap='gray')
    print(label_batch)
    break
# Out:
# first batch
# torch.Size([100, 1, 28, 28]) -> [batch_size, color channel, dimension, dimension]
# tensor([0, 1, 8, 0, 5, 4, 8, 8, 1, 5, 5, 5, 9, 7, 4, 4, 2, 8, 0, 6, 4, 5, 7, 1,
#         4, 3, 3, 9, 6, 5, 8, 1, 8, 2, 2, 8, 3, 0, 5, 3, 9, 8, 7, 1, 7, 4, 1, 8,
#         9, 4, 5, 3, 6, 2, 4, 2, 5, 4, 8, 5, 4, 8, 1, 3, 3, 6, 1, 6, 8, 8, 5, 8,
#         9, 7, 2, 1, 5, 6, 2, 5, 1, 2, 6, 5, 9, 3, 3, 3, 2, 2, 2, 0, 5, 4, 8, 8,
#         1, 2, 4, 2])

# %% [markdown]
# #### Let's set up a device too!
# #### In my case, I am running this on a M2 chip so would only be able to utilize MPS and no GPUs.
# #### If you have any local GPUs or cloud GPUs you can use, please feel free to change this part of the code.

# %%
# Please feel free to change this section according to your local/cloud GPU device

device = torch.device('mps') 

device
# Out:
# device(type='mps')

# %% [markdown]
# <p style="text-align: center; font-size:30px;">Discriminator Network</p>

# %% [markdown]
# #### The discriminator will take an image as input, and try to classify it as either fake or real.
# #### As we are just builing a simple GAN, we will simple create a simple feedforward network with 3 linear layers.
# #### If you want to see a more advanced version, take a look at my other notebook about DCGANs.

# %%
image_size = 784
hidden_size = 256

import torch.nn as nn 

D = nn.Sequential(
    nn.Linear(image_size, hidden_size),
    nn.LeakyReLU(0.2), 
    nn.Linear(hidden_size, hidden_size), 
    nn.LeakyReLU(0.2), 
    nn.Linear(hidden_size, 1), 
    nn.Sigmoid() 
)

D.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=784, out_features=256, bias=True)
#   (1): LeakyReLU(negative_slope=0.2)
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): LeakyReLU(negative_slope=0.2)
#   (4): Linear(in_features=256, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %% [markdown]
# #### LeakyReLU is slightly different from the original ReLU in the sense that it allows the pass of a small gradient signal for negative values, instead of none at all.
# #### For the discriminator, it will output a single value, between 0 and 1, which can be taken as the probability of the input image being fake.

# %% [markdown]
# <p style="text-align: center; font-size:30px;">Generator Network</p>

# %% [markdown]
# #### The generator's input is generally a vector or a matrix which is used as a seed for generating an image.

# %%
latent_size = 64

G = nn.Sequential(
    nn.Linear(latent_size, hidden_size), 
    nn.ReLU(), 
    nn.Linear(hidden_size, hidden_size), 
    nn.ReLU(), 
    nn.Linear(hidden_size, image_size),
    nn.Tanh()
)

# %% [markdown]
# #### Now since our Generator's output will be in the range of -1 and 1, we can denormalize the output and transform to view the image.

# %%
y = G(torch.randn(2, latent_size))
gen_imgs = denorm(y.reshape((-1, 28, 28)).detach())
plt.imshow(gen_imgs[0], cmap='gray')
plt.show()

# %%
plt.imshow(gen_imgs[1], cmap='gray');

# %% [markdown]
# #### Obviously, this is going to be just random noise, which is pretty useless to us.
# #### Now, let's see how we can train these two fellows to get better at their task.

# %%
G.to(device)
# Out:
# Sequential(
#   (0): Linear(in_features=64, out_features=256, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=256, out_features=256, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=256, out_features=784, bias=True)
#   (5): Tanh()
# )

# %% [markdown]
# <p style="text-align: center; font-size:30px;">Discriminator Training</p>

# %% [markdown]
# #### Since the discriminator is a binary classification model, we will use the binary cross entropy loss function to quantify how well it is able to differentiate between real and generated images.

# %%
criterion = nn.BCELoss()
d_optimizer = torch.optim.Adam(D.parameters(), lr = 0.0002)

def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

def train_discriminator(images):
    real_labels = torch.ones(batch_size, 1).to(device)
    fake_labels = torch.zeros(batch_size, 1).to(device)

    # Loss for real images
    outputs = D(images) # show the probability that the image is real
    d_loss_real = criterion(outputs, real_labels)
    real_score = outputs 

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    outputs = D(fake_images) # show the probability that the image is real
    d_loss_fake = criterion(outputs, fake_labels) 
    fake_score = outputs 

    # Combine losses
    d_loss = d_loss_real + d_loss_fake 
    # Reset gradients
    reset_grad()
    # Compute Gradients
    d_loss.backward()
    # Adjust parameters 
    d_optimizer.step()

    return d_loss, real_score, fake_score

# %% [markdown]
# #### The process is pretty straightforward.
# #### We expect the discriminator (perfect) to output 1 if the image was picked from the real dataset, and 0 if it was generated.
# #### We pass in real images first, and compute the loss.
# #### Then, we generate fake images using the generator, pass them into the discriminator and compute the loss.
# #### Finally, we add the two losses and use the overall loss to perform gradient descent to adjust the weights of the discriminator.
# #### This is how we train the discriminator.

# %% [markdown]
# <p style="text-align: center; font-size:30px;">Generator Training</p>

# %% [markdown]
# #### To me, training the discriminator is pretty straightforward and I could have guessed how it worked.
# #### However, what was tricky for me was training the generator.
# #### Apparently, we will use the discriminator as a part of the loss function.
# #### So, we generate a batch of images using the generator and pass them into the discriminator.
# #### We calculate the loss by setting the target labels to 1 (real).
# #### This is to ensure the generator's objective is to fool the discriminator; providing a fake image and saying it is a real one.
# #### We use this loss to perform gradient descent; changing the discriminator's weights, so it gets better at generating real-like images.
# #### In essence, the generator is doing its best to fool the discriminator to making it believe it is indeed giving it a real image, when it's not.

# %%
g_optimizer = torch.optim.Adam(G.parameters(), lr = 0.0002)

def train_generator():
    z = torch.randn(batch_size, latent_size).to(device)
    fake_images = G(z)
    labels = torch.ones(batch_size, 1).to(device) # To fake the discriminator that they are real images
    g_loss = criterion(D(fake_images), labels)

    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %% [markdown]
# <p style="text-align: center; font-size:30px;">Training the Model</p>

# %% [markdown]
# #### Let's create a directory where we can save intermediate outputs from the generator to visually inspect the progress of the model.

# %%
import os

sample_dir = '../data/samples' 
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

from IPython.display import Image
from torchvision.utils import save_image 

for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28) 
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break 

Image(os.path.join(sample_dir, 'real_images.png'))

# %%
# Helper function to save a batch of generated images to disk at the end of every epoch

sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)
    
# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %% [markdown]
# #### Now let's train!

# %%
# %%time

num_epochs = 300
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.reshape(batch_size, -1).to(device)
        
        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        g_loss, fake_images = train_generator()
        
        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}' 
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(), 
                          real_score.mean().item(), fake_score.mean().item()))
        
    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/300], Step [200/600], d_loss: 0.0439, g_loss: 3.8857, D(x): 0.99, D(G(z)): 0.04
# Epoch [0/300], Step [400/600], d_loss: 0.0476, g_loss: 5.7913, D(x): 0.99, D(G(z)): 0.04
# Epoch [0/300], Step [600/600], d_loss: 0.0502, g_loss: 4.9307, D(x): 0.99, D(G(z)): 0.03
# Saving fake_images-0001.png
# Epoch [1/300], Step [200/600], d_loss: 0.0305, g_loss: 5.9515, D(x): 0.99, D(G(z)): 0.02
# Epoch [1/300], Step [400/600], d_loss: 0.0972, g_loss: 3.1010, D(x): 0.97, D(G(z)): 0.06
# Epoch [1/300], Step [600/600], d_loss: 0.1022, g_loss: 4.3774, D(x): 0.97, D(G(z)): 0.06
# Saving fake_images-0002.png
# Epoch [2/300], Step [200/600], d_loss: 0.6406, g_loss: 3.0900, D(x): 0.87, D(G(z)): 0.30
# Epoch [2/300], Step [400/600], d_loss: 0.3250, g_loss: 3.7307, D(x): 0.89, D(G(z)): 0.11
# Epoch [2/300], Step [600/600], d_loss: 0.2061, g_loss: 4.0729, D(x): 0.95, D(G(z)): 0.10
# Saving fake_images-0003.png
# Epoch [3/300], Step [200/600], d_loss: 0.0898, g_loss: 3.5426, D(x): 0.97, D(G(z)): 0.05
# Epoch [3/300], Step [400/600], d_loss: 0.4563, g_loss: 3.5951, D(x): 0.83, D(G(z)): 0.12
# Epoch [3/300], Step [600/600], d_loss: 0.3141, g_loss: 4.7075, D(x): 0.85, D(G(z)): 0.05
# Saving fake_images-0004.png
# Epoch [4/300], Step [200/600], d_loss: 0.8917, g_loss: 2.4013, D(x): 0.78, D(G(z)): 0.32
# Epoch [4/300], Step [400/600], d_loss: 0.8232, g_loss: 2.5778, D(x): 0.81, D(G(z)): 0.28
# Epoch [4/300], Step [600/600], d_loss: 0.1574, g_loss: 3.8567, D(x): 0.97, D(G(z)): 0.09
# Saving fake_images-0005.png
# Epoch [5/300], Step [200/600], d_loss: 0.3567, g_loss: 3.7711, D(x): 0.89, D(G(z)): 0.13
# Epoch [5/300], Step [400/600], d_loss: 0.3434, g_loss: 3.6621, D(x): 0.95, D(G(z)): 0.20
# Epoch [5/300], Step [600/600], d_loss: 0.3866, g_loss: 5.1619, D(x): 0.87, D(G(z)): 0.08
# Saving fake_images-0006.png
# Epoch [6/300], Step [200/600], d_loss: 0.1559, g_loss: 3.4034, D(x): 0.94, D(G(z)): 0.06
# Epoch [6/300], Step [400/600], d_loss: 0.6004, g_loss: 2.5271, D(x): 0.86, D(G(z)): 0.25
# Epoch [6/300], Step [600/600], d_loss: 0.3630, g_loss: 2.7221, D(x): 0.92, D(G(z)): 0.18
# Saving fake_images-0007.png
# Epoch [7/300], Step [200/600], d_loss: 0.3172, g_loss: 3.1710, D(x): 0.95, D(G(z)): 0.19
# Epoch [7/300], Step [400/600], d_loss: 0.1965, g_loss: 3.7086, D(x): 0.93, D(G(z)): 0.07
# Epoch [7/300], Step [600/600], d_loss: 0.1777, g_loss: 3.5897, D(x): 0.94, D(G(z)): 0.07
# Saving fake_images-0008.png
# Epoch [8/300], Step [200/600], d_loss: 0.1091, g_loss: 5.2281, D(x): 0.97, D(G(z)): 0.05
# Epoch [8/300], Step [400/600], d_loss: 0.1784, g_loss: 3.8685, D(x): 0.96, D(G(z)): 0.05
# Epoch [8/300], Step [600/600], d_loss: 0.4773, g_loss: 4.6270, D(x): 0.85, D(G(z)): 0.05
# Saving fake_images-0009.png
# Epoch [9/300], Step [200/600], d_loss: 0.1826, g_loss: 5.0066, D(x): 0.95, D(G(z)): 0.07
# Epoch [9/300], Step [400/600], d_loss: 0.3185, g_loss: 4.6659, D(x): 0.93, D(G(z)): 0.08
# Epoch [9/300], Step [600/600], d_loss: 0.1886, g_loss: 4.1401, D(x): 0.94, D(G(z)): 0.07
# Saving fake_images-0010.png
# Epoch [10/300], Step [200/600], d_loss: 0.3143, g_loss: 5.0165, D(x): 0.89, D(G(z)): 0.04
# Epoch [10/300], Step [400/600], d_loss: 0.1376, g_loss: 4.6484, D(x): 0.97, D(G(z)): 0.07
# Epoch [10/300], Step [600/600], d_loss: 0.1105, g_loss: 5.0235, D(x): 0.96, D(G(z)): 0.02
# Saving fake_images-0011.png
# Epoch [11/300], Step [200/600], d_loss: 0.2333, g_loss: 4.4455, D(x): 0.90, D(G(z)): 0.03
# Epoch [11/300], Step [400/600], d_loss: 0.2314, g_loss: 4.4304, D(x): 0.95, D(G(z)): 0.06
# Epoch [11/300], Step [600/600], d_loss: 0.2525, g_loss: 4.4259, D(x): 0.95, D(G(z)): 0.11
# Saving fake_images-0012.png
# Epoch [12/300], Step [200/600], d_loss: 0.3129, g_loss: 3.6680, D(x): 0.89, D(G(z)): 0.07
# Epoch [12/300], Step [400/600], d_loss: 0.2004, g_loss: 4.5200, D(x): 0.93, D(G(z)): 0.03
# Epoch [12/300], Step [600/600], d_loss: 0.2505, g_loss: 4.9866, D(x): 0.91, D(G(z)): 0.07
# Saving fake_images-0013.png
# Epoch [13/300], Step [200/600], d_loss: 0.4039, g_loss: 4.4906, D(x): 0.88, D(G(z)): 0.09
# Epoch [13/300], Step [400/600], d_loss: 0.1777, g_loss: 5.0186, D(x): 0.93, D(G(z)): 0.02
# Epoch [13/300], Step [600/600], d_loss: 0.3769, g_loss: 3.5648, D(x): 0.87, D(G(z)): 0.05
# Saving fake_images-0014.png
# Epoch [14/300], Step [200/600], d_loss: 0.4884, g_loss: 4.0466, D(x): 0.90, D(G(z)): 0.17
# Epoch [14/300], Step [400/600], d_loss: 0.0845, g_loss: 5.0530, D(x): 0.97, D(G(z)): 0.04
# Epoch [14/300], Step [600/600], d_loss: 0.2180, g_loss: 3.9934, D(x): 0.91, D(G(z)): 0.04
# Saving fake_images-0015.png
# Epoch [15/300], Step [200/600], d_loss: 0.4568, g_loss: 4.1877, D(x): 0.90, D(G(z)): 0.10
# Epoch [15/300], Step [400/600], d_loss: 0.2381, g_loss: 4.6099, D(x): 0.93, D(G(z)): 0.07
# Epoch [15/300], Step [600/600], d_loss: 0.2632, g_loss: 5.0045, D(x): 0.93, D(G(z)): 0.09
# Saving fake_images-0016.png
# Epoch [16/300], Step [200/600], d_loss: 0.1662, g_loss: 4.0412, D(x): 0.96, D(G(z)): 0.07
# Epoch [16/300], Step [400/600], d_loss: 0.1486, g_loss: 4.7306, D(x): 0.92, D(G(z)): 0.02
# Epoch [16/300], Step [600/600], d_loss: 0.3686, g_loss: 3.0798, D(x): 0.93, D(G(z)): 0.16
# Saving fake_images-0017.png
# Epoch [17/300], Step [200/600], d_loss: 0.3251, g_loss: 4.8853, D(x): 0.90, D(G(z)): 0.07
# Epoch [17/300], Step [400/600], d_loss: 0.2078, g_loss: 3.9597, D(x): 0.94, D(G(z)): 0.08
# Epoch [17/300], Step [600/600], d_loss: 0.1384, g_loss: 3.6666, D(x): 0.94, D(G(z)): 0.04
# Saving fake_images-0018.png
# Epoch [18/300], Step [200/600], d_loss: 0.0981, g_loss: 4.6850, D(x): 0.97, D(G(z)): 0.06
# Epoch [18/300], Step [400/600], d_loss: 0.2101, g_loss: 4.5294, D(x): 0.93, D(G(z)): 0.06
# Epoch [18/300], Step [600/600], d_loss: 0.3206, g_loss: 4.6743, D(x): 0.89, D(G(z)): 0.02
# Saving fake_images-0019.png
# Epoch [19/300], Step [200/600], d_loss: 0.1870, g_loss: 7.2208, D(x): 0.94, D(G(z)): 0.05
# Epoch [19/300], Step [400/600], d_loss: 0.2373, g_loss: 4.3857, D(x): 0.94, D(G(z)): 0.08
# Epoch [19/300], Step [600/600], d_loss: 0.2149, g_loss: 4.8196, D(x): 0.98, D(G(z)): 0.13
# Saving fake_images-0020.png
# Epoch [20/300], Step [200/600], d_loss: 0.2241, g_loss: 4.9939, D(x): 0.96, D(G(z)): 0.11
# Epoch [20/300], Step [400/600], d_loss: 0.1724, g_loss: 4.0333, D(x): 0.97, D(G(z)): 0.09
# Epoch [20/300], Step [600/600], d_loss: 0.4112, g_loss: 4.1732, D(x): 0.85, D(G(z)): 0.02
# Saving fake_images-0021.png
# Epoch [21/300], Step [200/600], d_loss: 0.1350, g_loss: 3.7586, D(x): 0.97, D(G(z)): 0.08
# Epoch [21/300], Step [400/600], d_loss: 0.2224, g_loss: 3.9196, D(x): 0.95, D(G(z)): 0.09
# Epoch [21/300], Step [600/600], d_loss: 0.0950, g_loss: 5.8943, D(x): 0.97, D(G(z)): 0.04
# Saving fake_images-0022.png
# Epoch [22/300], Step [200/600], d_loss: 0.2644, g_loss: 5.6635, D(x): 0.94, D(G(z)): 0.07
# Epoch [22/300], Step [400/600], d_loss: 0.4631, g_loss: 4.7761, D(x): 0.88, D(G(z)): 0.09
# Epoch [22/300], Step [600/600], d_loss: 0.2788, g_loss: 4.7519, D(x): 0.93, D(G(z)): 0.12
# Saving fake_images-0023.png
# Epoch [23/300], Step [200/600], d_loss: 0.1320, g_loss: 4.1319, D(x): 0.96, D(G(z)): 0.06
# Epoch [23/300], Step [400/600], d_loss: 0.1152, g_loss: 4.6747, D(x): 0.97, D(G(z)): 0.05
# Epoch [23/300], Step [600/600], d_loss: 0.2165, g_loss: 4.6407, D(x): 0.93, D(G(z)): 0.07
# Saving fake_images-0024.png
# Epoch [24/300], Step [200/600], d_loss: 0.3176, g_loss: 5.7151, D(x): 0.97, D(G(z)): 0.19
# Epoch [24/300], Step [400/600], d_loss: 0.2674, g_loss: 4.7693, D(x): 0.93, D(G(z)): 0.08
# Epoch [24/300], Step [600/600], d_loss: 0.3256, g_loss: 4.9375, D(x): 0.89, D(G(z)): 0.07
# Saving fake_images-0025.png
# Epoch [25/300], Step [200/600], d_loss: 0.2929, g_loss: 4.8985, D(x): 0.99, D(G(z)): 0.18
# Epoch [25/300], Step [400/600], d_loss: 0.2034, g_loss: 4.4093, D(x): 0.96, D(G(z)): 0.10
# Epoch [25/300], Step [600/600], d_loss: 0.2562, g_loss: 4.0708, D(x): 0.93, D(G(z)): 0.09
# Saving fake_images-0026.png
# Epoch [26/300], Step [200/600], d_loss: 0.4326, g_loss: 2.8715, D(x): 0.90, D(G(z)): 0.09
# Epoch [26/300], Step [400/600], d_loss: 0.4547, g_loss: 3.5540, D(x): 0.82, D(G(z)): 0.02
# Epoch [26/300], Step [600/600], d_loss: 0.4003, g_loss: 2.6951, D(x): 0.89, D(G(z)): 0.10
# Saving fake_images-0027.png
# Epoch [27/300], Step [200/600], d_loss: 0.2957, g_loss: 4.1342, D(x): 0.90, D(G(z)): 0.07
# Epoch [27/300], Step [400/600], d_loss: 0.4285, g_loss: 4.2915, D(x): 0.91, D(G(z)): 0.14
# Epoch [27/300], Step [600/600], d_loss: 0.2585, g_loss: 5.4817, D(x): 0.90, D(G(z)): 0.05
# Saving fake_images-0028.png
# Epoch [28/300], Step [200/600], d_loss: 0.4836, g_loss: 3.6440, D(x): 0.84, D(G(z)): 0.11
# Epoch [28/300], Step [400/600], d_loss: 0.1812, g_loss: 4.4826, D(x): 0.95, D(G(z)): 0.05
# Epoch [28/300], Step [600/600], d_loss: 0.2817, g_loss: 4.1942, D(x): 0.95, D(G(z)): 0.15
# Saving fake_images-0029.png
# Epoch [29/300], Step [200/600], d_loss: 0.2334, g_loss: 4.9353, D(x): 0.92, D(G(z)): 0.05
# Epoch [29/300], Step [400/600], d_loss: 0.1812, g_loss: 5.5933, D(x): 0.94, D(G(z)): 0.06
# Epoch [29/300], Step [600/600], d_loss: 0.3012, g_loss: 3.6840, D(x): 0.91, D(G(z)): 0.12
# Saving fake_images-0030.png
# Epoch [30/300], Step [200/600], d_loss: 0.3409, g_loss: 3.5127, D(x): 0.88, D(G(z)): 0.11
# Epoch [30/300], Step [400/600], d_loss: 0.3007, g_loss: 3.4555, D(x): 0.89, D(G(z)): 0.09
# Epoch [30/300], Step [600/600], d_loss: 0.2183, g_loss: 4.2549, D(x): 0.90, D(G(z)): 0.05
# Saving fake_images-0031.png
# Epoch [31/300], Step [200/600], d_loss: 0.3909, g_loss: 4.1670, D(x): 0.90, D(G(z)): 0.11
# Epoch [31/300], Step [400/600], d_loss: 0.4969, g_loss: 3.6166, D(x): 0.96, D(G(z)): 0.26
# Epoch [31/300], Step [600/600], d_loss: 0.4655, g_loss: 3.7969, D(x): 0.93, D(G(z)): 0.21
# Saving fake_images-0032.png
# Epoch [32/300], Step [200/600], d_loss: 0.3772, g_loss: 2.7627, D(x): 0.89, D(G(z)): 0.08
# Epoch [32/300], Step [400/600], d_loss: 0.3956, g_loss: 4.7064, D(x): 0.87, D(G(z)): 0.06
# Epoch [32/300], Step [600/600], d_loss: 0.5824, g_loss: 3.1732, D(x): 0.89, D(G(z)): 0.23
# Saving fake_images-0033.png
# Epoch [33/300], Step [200/600], d_loss: 0.3530, g_loss: 3.2467, D(x): 0.93, D(G(z)): 0.16
# Epoch [33/300], Step [400/600], d_loss: 0.5745, g_loss: 2.6377, D(x): 0.91, D(G(z)): 0.23
# Epoch [33/300], Step [600/600], d_loss: 0.6741, g_loss: 3.0358, D(x): 0.88, D(G(z)): 0.25
# Saving fake_images-0034.png
# Epoch [34/300], Step [200/600], d_loss: 0.5044, g_loss: 4.1039, D(x): 0.81, D(G(z)): 0.07
# Epoch [34/300], Step [400/600], d_loss: 0.4062, g_loss: 4.5149, D(x): 0.88, D(G(z)): 0.12
# Epoch [34/300], Step [600/600], d_loss: 0.4952, g_loss: 3.9109, D(x): 0.90, D(G(z)): 0.19
# Saving fake_images-0035.png
# Epoch [35/300], Step [200/600], d_loss: 0.3181, g_loss: 2.8816, D(x): 0.90, D(G(z)): 0.12
# Epoch [35/300], Step [400/600], d_loss: 0.3731, g_loss: 3.7594, D(x): 0.89, D(G(z)): 0.12
# Epoch [35/300], Step [600/600], d_loss: 0.6118, g_loss: 2.9927, D(x): 0.81, D(G(z)): 0.15
# Saving fake_images-0036.png
# Epoch [36/300], Step [200/600], d_loss: 0.5888, g_loss: 3.4022, D(x): 0.81, D(G(z)): 0.15
# Epoch [36/300], Step [400/600], d_loss: 0.5519, g_loss: 3.2407, D(x): 0.87, D(G(z)): 0.17
# Epoch [36/300], Step [600/600], d_loss: 0.5874, g_loss: 3.2448, D(x): 0.80, D(G(z)): 0.14
# Saving fake_images-0037.png
# Epoch [37/300], Step [200/600], d_loss: 0.4664, g_loss: 2.3719, D(x): 0.84, D(G(z)): 0.09
# Epoch [37/300], Step [400/600], d_loss: 0.4218, g_loss: 2.8025, D(x): 0.92, D(G(z)): 0.19
# Epoch [37/300], Step [600/600], d_loss: 0.5233, g_loss: 2.9963, D(x): 0.88, D(G(z)): 0.21
# Saving fake_images-0038.png
# Epoch [38/300], Step [200/600], d_loss: 0.3425, g_loss: 2.6322, D(x): 0.91, D(G(z)): 0.14
# Epoch [38/300], Step [400/600], d_loss: 0.6456, g_loss: 2.8953, D(x): 0.76, D(G(z)): 0.12
# Epoch [38/300], Step [600/600], d_loss: 0.4341, g_loss: 2.6815, D(x): 0.89, D(G(z)): 0.12
# Saving fake_images-0039.png
# Epoch [39/300], Step [200/600], d_loss: 0.3017, g_loss: 3.3794, D(x): 0.91, D(G(z)): 0.11
# Epoch [39/300], Step [400/600], d_loss: 0.3939, g_loss: 3.1256, D(x): 0.88, D(G(z)): 0.15
# Epoch [39/300], Step [600/600], d_loss: 0.4023, g_loss: 3.7416, D(x): 0.89, D(G(z)): 0.15
# Saving fake_images-0040.png
# Epoch [40/300], Step [200/600], d_loss: 0.3668, g_loss: 3.5276, D(x): 0.89, D(G(z)): 0.10
# Epoch [40/300], Step [400/600], d_loss: 0.4218, g_loss: 3.3398, D(x): 0.86, D(G(z)): 0.11
# Epoch [40/300], Step [600/600], d_loss: 0.4831, g_loss: 3.3753, D(x): 0.89, D(G(z)): 0.21
# Saving fake_images-0041.png
# Epoch [41/300], Step [200/600], d_loss: 0.3591, g_loss: 3.9530, D(x): 0.89, D(G(z)): 0.12
# Epoch [41/300], Step [400/600], d_loss: 0.3487, g_loss: 2.7241, D(x): 0.87, D(G(z)): 0.09
# Epoch [41/300], Step [600/600], d_loss: 0.5329, g_loss: 2.5549, D(x): 0.86, D(G(z)): 0.18
# Saving fake_images-0042.png
# Epoch [42/300], Step [200/600], d_loss: 0.2882, g_loss: 4.1486, D(x): 0.90, D(G(z)): 0.08
# Epoch [42/300], Step [400/600], d_loss: 0.5923, g_loss: 3.1592, D(x): 0.79, D(G(z)): 0.09
# Epoch [42/300], Step [600/600], d_loss: 0.5311, g_loss: 2.3767, D(x): 0.85, D(G(z)): 0.19
# Saving fake_images-0043.png
# Epoch [43/300], Step [200/600], d_loss: 0.5645, g_loss: 2.8881, D(x): 0.85, D(G(z)): 0.18
# Epoch [43/300], Step [400/600], d_loss: 0.6974, g_loss: 2.6478, D(x): 0.78, D(G(z)): 0.16
# Epoch [43/300], Step [600/600], d_loss: 0.4909, g_loss: 2.9604, D(x): 0.81, D(G(z)): 0.11
# Saving fake_images-0044.png
# Epoch [44/300], Step [200/600], d_loss: 0.5097, g_loss: 2.6655, D(x): 0.89, D(G(z)): 0.23
# Epoch [44/300], Step [400/600], d_loss: 0.4523, g_loss: 2.3029, D(x): 0.88, D(G(z)): 0.19
# Epoch [44/300], Step [600/600], d_loss: 0.5013, g_loss: 2.7614, D(x): 0.86, D(G(z)): 0.19
# Saving fake_images-0045.png
# Epoch [45/300], Step [200/600], d_loss: 0.4691, g_loss: 3.0935, D(x): 0.90, D(G(z)): 0.20
# Epoch [45/300], Step [400/600], d_loss: 0.5545, g_loss: 2.5273, D(x): 0.83, D(G(z)): 0.19
# Epoch [45/300], Step [600/600], d_loss: 0.5223, g_loss: 2.5662, D(x): 0.85, D(G(z)): 0.19
# Saving fake_images-0046.png
# Epoch [46/300], Step [200/600], d_loss: 0.6229, g_loss: 2.3263, D(x): 0.86, D(G(z)): 0.26
# Epoch [46/300], Step [400/600], d_loss: 0.7734, g_loss: 1.9192, D(x): 0.75, D(G(z)): 0.19
# Epoch [46/300], Step [600/600], d_loss: 0.4930, g_loss: 2.6853, D(x): 0.77, D(G(z)): 0.09
# Saving fake_images-0047.png
# Epoch [47/300], Step [200/600], d_loss: 0.4057, g_loss: 3.4277, D(x): 0.90, D(G(z)): 0.17
# Epoch [47/300], Step [400/600], d_loss: 0.5050, g_loss: 2.6625, D(x): 0.82, D(G(z)): 0.11
# Epoch [47/300], Step [600/600], d_loss: 0.8289, g_loss: 2.6957, D(x): 0.71, D(G(z)): 0.15
# Saving fake_images-0048.png
# Epoch [48/300], Step [200/600], d_loss: 0.5448, g_loss: 2.3873, D(x): 0.82, D(G(z)): 0.18
# Epoch [48/300], Step [400/600], d_loss: 0.6613, g_loss: 1.8908, D(x): 0.79, D(G(z)): 0.20
# Epoch [48/300], Step [600/600], d_loss: 0.6338, g_loss: 2.5081, D(x): 0.81, D(G(z)): 0.19
# Saving fake_images-0049.png
# Epoch [49/300], Step [200/600], d_loss: 0.4948, g_loss: 3.1837, D(x): 0.81, D(G(z)): 0.15
# Epoch [49/300], Step [400/600], d_loss: 0.6786, g_loss: 2.7093, D(x): 0.74, D(G(z)): 0.13
# Epoch [49/300], Step [600/600], d_loss: 0.5249, g_loss: 4.0300, D(x): 0.79, D(G(z)): 0.10
# Saving fake_images-0050.png
# Epoch [50/300], Step [200/600], d_loss: 0.5280, g_loss: 3.1456, D(x): 0.85, D(G(z)): 0.22
# Epoch [50/300], Step [400/600], d_loss: 0.4812, g_loss: 3.0857, D(x): 0.86, D(G(z)): 0.18
# Epoch [50/300], Step [600/600], d_loss: 0.5353, g_loss: 2.7640, D(x): 0.90, D(G(z)): 0.25
# Saving fake_images-0051.png
# Epoch [51/300], Step [200/600], d_loss: 0.6200, g_loss: 2.8945, D(x): 0.79, D(G(z)): 0.18
# Epoch [51/300], Step [400/600], d_loss: 0.5223, g_loss: 2.5286, D(x): 0.87, D(G(z)): 0.22
# Epoch [51/300], Step [600/600], d_loss: 0.4981, g_loss: 2.9400, D(x): 0.85, D(G(z)): 0.17
# Saving fake_images-0052.png
# Epoch [52/300], Step [200/600], d_loss: 0.5667, g_loss: 2.2981, D(x): 0.84, D(G(z)): 0.20
# Epoch [52/300], Step [400/600], d_loss: 0.7212, g_loss: 1.8740, D(x): 0.79, D(G(z)): 0.21
# Epoch [52/300], Step [600/600], d_loss: 0.6267, g_loss: 1.6630, D(x): 0.90, D(G(z)): 0.28
# Saving fake_images-0053.png
# Epoch [53/300], Step [200/600], d_loss: 0.5984, g_loss: 3.7319, D(x): 0.76, D(G(z)): 0.07
# Epoch [53/300], Step [400/600], d_loss: 0.3458, g_loss: 2.8625, D(x): 0.87, D(G(z)): 0.14
# Epoch [53/300], Step [600/600], d_loss: 0.6351, g_loss: 2.3325, D(x): 0.85, D(G(z)): 0.26
# Saving fake_images-0054.png
# Epoch [54/300], Step [200/600], d_loss: 0.5758, g_loss: 2.4649, D(x): 0.76, D(G(z)): 0.10
# Epoch [54/300], Step [400/600], d_loss: 0.5431, g_loss: 2.7572, D(x): 0.81, D(G(z)): 0.17
# Epoch [54/300], Step [600/600], d_loss: 0.5608, g_loss: 2.9764, D(x): 0.81, D(G(z)): 0.18
# Saving fake_images-0055.png
# Epoch [55/300], Step [200/600], d_loss: 0.4926, g_loss: 2.3244, D(x): 0.86, D(G(z)): 0.21
# Epoch [55/300], Step [400/600], d_loss: 0.5696, g_loss: 2.4701, D(x): 0.78, D(G(z)): 0.15
# Epoch [55/300], Step [600/600], d_loss: 0.4831, g_loss: 2.3256, D(x): 0.86, D(G(z)): 0.20
# Saving fake_images-0056.png
# Epoch [56/300], Step [200/600], d_loss: 0.4695, g_loss: 2.9082, D(x): 0.81, D(G(z)): 0.12
# Epoch [56/300], Step [400/600], d_loss: 0.4482, g_loss: 2.6462, D(x): 0.91, D(G(z)): 0.23
# Epoch [56/300], Step [600/600], d_loss: 0.5882, g_loss: 1.9756, D(x): 0.78, D(G(z)): 0.14
# Saving fake_images-0057.png
# Epoch [57/300], Step [200/600], d_loss: 0.5656, g_loss: 2.1347, D(x): 0.82, D(G(z)): 0.21
# Epoch [57/300], Step [400/600], d_loss: 0.5390, g_loss: 2.8787, D(x): 0.84, D(G(z)): 0.18
# Epoch [57/300], Step [600/600], d_loss: 0.5611, g_loss: 3.1973, D(x): 0.79, D(G(z)): 0.13
# Saving fake_images-0058.png
# Epoch [58/300], Step [200/600], d_loss: 0.5454, g_loss: 2.5758, D(x): 0.86, D(G(z)): 0.21
# Epoch [58/300], Step [400/600], d_loss: 0.7832, g_loss: 2.7091, D(x): 0.72, D(G(z)): 0.21
# Epoch [58/300], Step [600/600], d_loss: 0.5661, g_loss: 2.2977, D(x): 0.90, D(G(z)): 0.27
# Saving fake_images-0059.png
# Epoch [59/300], Step [200/600], d_loss: 0.4719, g_loss: 3.0476, D(x): 0.80, D(G(z)): 0.09
# Epoch [59/300], Step [400/600], d_loss: 0.6021, g_loss: 2.3315, D(x): 0.79, D(G(z)): 0.20
# Epoch [59/300], Step [600/600], d_loss: 0.5262, g_loss: 2.4906, D(x): 0.82, D(G(z)): 0.19
# Saving fake_images-0060.png
# Epoch [60/300], Step [200/600], d_loss: 0.6593, g_loss: 2.1254, D(x): 0.79, D(G(z)): 0.21
# Epoch [60/300], Step [400/600], d_loss: 0.6279, g_loss: 1.7760, D(x): 0.83, D(G(z)): 0.22
# Epoch [60/300], Step [600/600], d_loss: 0.4486, g_loss: 2.6446, D(x): 0.83, D(G(z)): 0.14
# Saving fake_images-0061.png
# Epoch [61/300], Step [200/600], d_loss: 0.6059, g_loss: 2.0133, D(x): 0.83, D(G(z)): 0.22
# Epoch [61/300], Step [400/600], d_loss: 0.4737, g_loss: 1.5954, D(x): 0.85, D(G(z)): 0.19
# Epoch [61/300], Step [600/600], d_loss: 0.5767, g_loss: 2.9218, D(x): 0.78, D(G(z)): 0.15
# Saving fake_images-0062.png
# Epoch [62/300], Step [200/600], d_loss: 0.6868, g_loss: 1.9987, D(x): 0.81, D(G(z)): 0.24
# Epoch [62/300], Step [400/600], d_loss: 0.8649, g_loss: 2.4658, D(x): 0.71, D(G(z)): 0.16
# Epoch [62/300], Step [600/600], d_loss: 0.5862, g_loss: 2.0746, D(x): 0.81, D(G(z)): 0.18
# Saving fake_images-0063.png
# Epoch [63/300], Step [200/600], d_loss: 0.5976, g_loss: 2.0763, D(x): 0.80, D(G(z)): 0.17
# Epoch [63/300], Step [400/600], d_loss: 0.6330, g_loss: 1.7066, D(x): 0.78, D(G(z)): 0.18
# Epoch [63/300], Step [600/600], d_loss: 0.6745, g_loss: 2.4328, D(x): 0.86, D(G(z)): 0.29
# Saving fake_images-0064.png
# Epoch [64/300], Step [200/600], d_loss: 0.5723, g_loss: 2.4915, D(x): 0.74, D(G(z)): 0.11
# Epoch [64/300], Step [400/600], d_loss: 0.6191, g_loss: 2.1532, D(x): 0.82, D(G(z)): 0.24
# Epoch [64/300], Step [600/600], d_loss: 0.5674, g_loss: 2.2624, D(x): 0.85, D(G(z)): 0.25
# Saving fake_images-0065.png
# Epoch [65/300], Step [200/600], d_loss: 0.6373, g_loss: 2.2759, D(x): 0.87, D(G(z)): 0.29
# Epoch [65/300], Step [400/600], d_loss: 0.7358, g_loss: 1.8513, D(x): 0.69, D(G(z)): 0.17
# Epoch [65/300], Step [600/600], d_loss: 0.6253, g_loss: 1.6588, D(x): 0.79, D(G(z)): 0.21
# Saving fake_images-0066.png
# Epoch [66/300], Step [200/600], d_loss: 0.6814, g_loss: 2.1467, D(x): 0.76, D(G(z)): 0.21
# Epoch [66/300], Step [400/600], d_loss: 0.5728, g_loss: 2.9446, D(x): 0.72, D(G(z)): 0.10
# Epoch [66/300], Step [600/600], d_loss: 0.6919, g_loss: 2.6088, D(x): 0.74, D(G(z)): 0.17
# Saving fake_images-0067.png
# Epoch [67/300], Step [200/600], d_loss: 0.6275, g_loss: 2.4587, D(x): 0.80, D(G(z)): 0.22
# Epoch [67/300], Step [400/600], d_loss: 0.6424, g_loss: 2.4362, D(x): 0.79, D(G(z)): 0.21
# Epoch [67/300], Step [600/600], d_loss: 0.5323, g_loss: 2.5281, D(x): 0.83, D(G(z)): 0.15
# Saving fake_images-0068.png
# Epoch [68/300], Step [200/600], d_loss: 0.6421, g_loss: 1.8476, D(x): 0.76, D(G(z)): 0.21
# Epoch [68/300], Step [400/600], d_loss: 0.6394, g_loss: 2.6451, D(x): 0.74, D(G(z)): 0.10
# Epoch [68/300], Step [600/600], d_loss: 0.8082, g_loss: 2.5121, D(x): 0.73, D(G(z)): 0.20
# Saving fake_images-0069.png
# Epoch [69/300], Step [200/600], d_loss: 0.6897, g_loss: 2.3248, D(x): 0.79, D(G(z)): 0.23
# Epoch [69/300], Step [400/600], d_loss: 0.8536, g_loss: 1.7700, D(x): 0.67, D(G(z)): 0.20
# Epoch [69/300], Step [600/600], d_loss: 0.8147, g_loss: 2.0878, D(x): 0.75, D(G(z)): 0.23
# Saving fake_images-0070.png
# Epoch [70/300], Step [200/600], d_loss: 0.6716, g_loss: 2.4864, D(x): 0.74, D(G(z)): 0.18
# Epoch [70/300], Step [400/600], d_loss: 0.7110, g_loss: 1.2759, D(x): 0.80, D(G(z)): 0.26
# Epoch [70/300], Step [600/600], d_loss: 0.5740, g_loss: 1.6696, D(x): 0.84, D(G(z)): 0.23
# Saving fake_images-0071.png
# Epoch [71/300], Step [200/600], d_loss: 0.7113, g_loss: 1.8021, D(x): 0.81, D(G(z)): 0.25
# Epoch [71/300], Step [400/600], d_loss: 0.6313, g_loss: 2.8434, D(x): 0.87, D(G(z)): 0.28
# Epoch [71/300], Step [600/600], d_loss: 0.5670, g_loss: 2.6194, D(x): 0.78, D(G(z)): 0.17
# Saving fake_images-0072.png
# Epoch [72/300], Step [200/600], d_loss: 0.6597, g_loss: 2.1431, D(x): 0.75, D(G(z)): 0.16
# Epoch [72/300], Step [400/600], d_loss: 0.5251, g_loss: 2.7920, D(x): 0.78, D(G(z)): 0.13
# Epoch [72/300], Step [600/600], d_loss: 0.7357, g_loss: 2.3932, D(x): 0.78, D(G(z)): 0.24
# Saving fake_images-0073.png
# Epoch [73/300], Step [200/600], d_loss: 0.7354, g_loss: 2.3229, D(x): 0.87, D(G(z)): 0.31
# Epoch [73/300], Step [400/600], d_loss: 0.5137, g_loss: 2.2887, D(x): 0.84, D(G(z)): 0.17
# Epoch [73/300], Step [600/600], d_loss: 0.6536, g_loss: 2.2083, D(x): 0.79, D(G(z)): 0.20
# Saving fake_images-0074.png
# Epoch [74/300], Step [200/600], d_loss: 0.5762, g_loss: 2.5541, D(x): 0.75, D(G(z)): 0.11
# Epoch [74/300], Step [400/600], d_loss: 0.8600, g_loss: 1.8492, D(x): 0.80, D(G(z)): 0.30
# Epoch [74/300], Step [600/600], d_loss: 0.4604, g_loss: 2.3706, D(x): 0.82, D(G(z)): 0.15
# Saving fake_images-0075.png
# Epoch [75/300], Step [200/600], d_loss: 0.6696, g_loss: 2.1562, D(x): 0.79, D(G(z)): 0.25
# Epoch [75/300], Step [400/600], d_loss: 0.9882, g_loss: 2.0013, D(x): 0.75, D(G(z)): 0.34
# Epoch [75/300], Step [600/600], d_loss: 0.5419, g_loss: 2.3003, D(x): 0.77, D(G(z)): 0.15
# Saving fake_images-0076.png
# Epoch [76/300], Step [200/600], d_loss: 0.9687, g_loss: 1.5800, D(x): 0.80, D(G(z)): 0.39
# Epoch [76/300], Step [400/600], d_loss: 0.7842, g_loss: 2.3179, D(x): 0.74, D(G(z)): 0.22
# Epoch [76/300], Step [600/600], d_loss: 0.6264, g_loss: 1.5983, D(x): 0.86, D(G(z)): 0.30
# Saving fake_images-0077.png
# Epoch [77/300], Step [200/600], d_loss: 0.8819, g_loss: 2.4870, D(x): 0.67, D(G(z)): 0.15
# Epoch [77/300], Step [400/600], d_loss: 0.8339, g_loss: 1.9785, D(x): 0.78, D(G(z)): 0.30
# Epoch [77/300], Step [600/600], d_loss: 0.7927, g_loss: 2.1775, D(x): 0.71, D(G(z)): 0.19
# Saving fake_images-0078.png
# Epoch [78/300], Step [200/600], d_loss: 0.5501, g_loss: 2.0390, D(x): 0.80, D(G(z)): 0.20
# Epoch [78/300], Step [400/600], d_loss: 0.6749, g_loss: 2.7362, D(x): 0.79, D(G(z)): 0.19
# Epoch [78/300], Step [600/600], d_loss: 0.9253, g_loss: 1.5439, D(x): 0.76, D(G(z)): 0.35
# Saving fake_images-0079.png
# Epoch [79/300], Step [200/600], d_loss: 0.8105, g_loss: 1.7615, D(x): 0.78, D(G(z)): 0.26
# Epoch [79/300], Step [400/600], d_loss: 0.6927, g_loss: 1.9617, D(x): 0.82, D(G(z)): 0.24
# Epoch [79/300], Step [600/600], d_loss: 0.6217, g_loss: 2.4490, D(x): 0.76, D(G(z)): 0.15
# Saving fake_images-0080.png
# Epoch [80/300], Step [200/600], d_loss: 0.5099, g_loss: 2.9772, D(x): 0.85, D(G(z)): 0.20
# Epoch [80/300], Step [400/600], d_loss: 0.6926, g_loss: 2.4851, D(x): 0.74, D(G(z)): 0.16
# Epoch [80/300], Step [600/600], d_loss: 0.6531, g_loss: 2.6085, D(x): 0.79, D(G(z)): 0.19
# Saving fake_images-0081.png
# Epoch [81/300], Step [200/600], d_loss: 0.6896, g_loss: 1.6792, D(x): 0.75, D(G(z)): 0.20
# Epoch [81/300], Step [400/600], d_loss: 0.6946, g_loss: 1.7281, D(x): 0.80, D(G(z)): 0.24
# Epoch [81/300], Step [600/600], d_loss: 0.8390, g_loss: 1.9215, D(x): 0.72, D(G(z)): 0.24
# Saving fake_images-0082.png
# Epoch [82/300], Step [200/600], d_loss: 1.0300, g_loss: 1.7452, D(x): 0.68, D(G(z)): 0.25
# Epoch [82/300], Step [400/600], d_loss: 0.8899, g_loss: 1.3284, D(x): 0.82, D(G(z)): 0.40
# Epoch [82/300], Step [600/600], d_loss: 0.7210, g_loss: 1.4057, D(x): 0.84, D(G(z)): 0.32
# Saving fake_images-0083.png
# Epoch [83/300], Step [200/600], d_loss: 0.5955, g_loss: 2.5036, D(x): 0.79, D(G(z)): 0.18
# Epoch [83/300], Step [400/600], d_loss: 0.8008, g_loss: 1.8653, D(x): 0.80, D(G(z)): 0.30
# Epoch [83/300], Step [600/600], d_loss: 0.6352, g_loss: 2.6741, D(x): 0.79, D(G(z)): 0.19
# Saving fake_images-0084.png
# Epoch [84/300], Step [200/600], d_loss: 0.7253, g_loss: 2.0414, D(x): 0.81, D(G(z)): 0.24
# Epoch [84/300], Step [400/600], d_loss: 0.5905, g_loss: 2.4043, D(x): 0.82, D(G(z)): 0.20
# Epoch [84/300], Step [600/600], d_loss: 0.6269, g_loss: 2.0285, D(x): 0.80, D(G(z)): 0.23
# Saving fake_images-0085.png
# Epoch [85/300], Step [200/600], d_loss: 0.6099, g_loss: 2.6318, D(x): 0.79, D(G(z)): 0.21
# Epoch [85/300], Step [400/600], d_loss: 0.9537, g_loss: 2.1107, D(x): 0.67, D(G(z)): 0.18
# Epoch [85/300], Step [600/600], d_loss: 0.5041, g_loss: 2.7131, D(x): 0.84, D(G(z)): 0.19
# Saving fake_images-0086.png
# Epoch [86/300], Step [200/600], d_loss: 0.6125, g_loss: 1.9155, D(x): 0.80, D(G(z)): 0.23
# Epoch [86/300], Step [400/600], d_loss: 0.7053, g_loss: 1.9746, D(x): 0.81, D(G(z)): 0.29
# Epoch [86/300], Step [600/600], d_loss: 0.6376, g_loss: 2.7373, D(x): 0.77, D(G(z)): 0.21
# Saving fake_images-0087.png
# Epoch [87/300], Step [200/600], d_loss: 0.6606, g_loss: 2.2223, D(x): 0.81, D(G(z)): 0.25
# Epoch [87/300], Step [400/600], d_loss: 0.6845, g_loss: 2.1125, D(x): 0.78, D(G(z)): 0.22
# Epoch [87/300], Step [600/600], d_loss: 0.7517, g_loss: 1.8326, D(x): 0.76, D(G(z)): 0.25
# Saving fake_images-0088.png
# Epoch [88/300], Step [200/600], d_loss: 0.7066, g_loss: 2.2535, D(x): 0.72, D(G(z)): 0.13
# Epoch [88/300], Step [400/600], d_loss: 0.7286, g_loss: 2.1855, D(x): 0.77, D(G(z)): 0.27
# Epoch [88/300], Step [600/600], d_loss: 0.7610, g_loss: 2.1397, D(x): 0.71, D(G(z)): 0.14
# Saving fake_images-0089.png
# Epoch [89/300], Step [200/600], d_loss: 0.5694, g_loss: 1.9849, D(x): 0.75, D(G(z)): 0.12
# Epoch [89/300], Step [400/600], d_loss: 0.6683, g_loss: 1.8286, D(x): 0.81, D(G(z)): 0.27
# Epoch [89/300], Step [600/600], d_loss: 0.6745, g_loss: 1.9829, D(x): 0.79, D(G(z)): 0.27
# Saving fake_images-0090.png
# Epoch [90/300], Step [200/600], d_loss: 0.7568, g_loss: 2.2749, D(x): 0.82, D(G(z)): 0.32
# Epoch [90/300], Step [400/600], d_loss: 0.5502, g_loss: 2.2645, D(x): 0.77, D(G(z)): 0.16
# Epoch [90/300], Step [600/600], d_loss: 0.7143, g_loss: 1.9560, D(x): 0.75, D(G(z)): 0.21
# Saving fake_images-0091.png
# Epoch [91/300], Step [200/600], d_loss: 0.9218, g_loss: 2.8574, D(x): 0.73, D(G(z)): 0.28
# Epoch [91/300], Step [400/600], d_loss: 0.7901, g_loss: 1.9264, D(x): 0.79, D(G(z)): 0.27
# Epoch [91/300], Step [600/600], d_loss: 0.6478, g_loss: 2.1859, D(x): 0.80, D(G(z)): 0.24
# Saving fake_images-0092.png
# Epoch [92/300], Step [200/600], d_loss: 0.7561, g_loss: 2.2881, D(x): 0.71, D(G(z)): 0.20
# Epoch [92/300], Step [400/600], d_loss: 0.6812, g_loss: 1.9689, D(x): 0.73, D(G(z)): 0.17
# Epoch [92/300], Step [600/600], d_loss: 0.8869, g_loss: 1.7355, D(x): 0.66, D(G(z)): 0.21
# Saving fake_images-0093.png
# Epoch [93/300], Step [200/600], d_loss: 0.6969, g_loss: 1.9735, D(x): 0.73, D(G(z)): 0.17
# Epoch [93/300], Step [400/600], d_loss: 0.9524, g_loss: 1.6219, D(x): 0.67, D(G(z)): 0.29
# Epoch [93/300], Step [600/600], d_loss: 0.7357, g_loss: 1.9084, D(x): 0.78, D(G(z)): 0.25
# Saving fake_images-0094.png
# Epoch [94/300], Step [200/600], d_loss: 0.7512, g_loss: 2.0572, D(x): 0.76, D(G(z)): 0.26
# Epoch [94/300], Step [400/600], d_loss: 0.8130, g_loss: 1.7479, D(x): 0.82, D(G(z)): 0.33
# Epoch [94/300], Step [600/600], d_loss: 0.6301, g_loss: 1.8600, D(x): 0.79, D(G(z)): 0.21
# Saving fake_images-0095.png
# Epoch [95/300], Step [200/600], d_loss: 0.6962, g_loss: 1.6522, D(x): 0.76, D(G(z)): 0.22
# Epoch [95/300], Step [400/600], d_loss: 0.8785, g_loss: 1.9184, D(x): 0.79, D(G(z)): 0.34
# Epoch [95/300], Step [600/600], d_loss: 0.9748, g_loss: 1.6088, D(x): 0.68, D(G(z)): 0.25
# Saving fake_images-0096.png
# Epoch [96/300], Step [200/600], d_loss: 0.9215, g_loss: 1.8995, D(x): 0.74, D(G(z)): 0.31
# Epoch [96/300], Step [400/600], d_loss: 0.7080, g_loss: 2.1573, D(x): 0.68, D(G(z)): 0.13
# Epoch [96/300], Step [600/600], d_loss: 0.9131, g_loss: 2.0346, D(x): 0.75, D(G(z)): 0.30
# Saving fake_images-0097.png
# Epoch [97/300], Step [200/600], d_loss: 0.6180, g_loss: 1.9307, D(x): 0.79, D(G(z)): 0.21
# Epoch [97/300], Step [400/600], d_loss: 0.9105, g_loss: 1.9780, D(x): 0.78, D(G(z)): 0.35
# Epoch [97/300], Step [600/600], d_loss: 0.8739, g_loss: 1.4322, D(x): 0.77, D(G(z)): 0.35
# Saving fake_images-0098.png
# Epoch [98/300], Step [200/600], d_loss: 1.0412, g_loss: 1.6185, D(x): 0.67, D(G(z)): 0.31
# Epoch [98/300], Step [400/600], d_loss: 1.0202, g_loss: 2.1788, D(x): 0.62, D(G(z)): 0.19
# Epoch [98/300], Step [600/600], d_loss: 0.6124, g_loss: 2.3174, D(x): 0.77, D(G(z)): 0.20
# Saving fake_images-0099.png
# Epoch [99/300], Step [200/600], d_loss: 0.7182, g_loss: 2.1046, D(x): 0.75, D(G(z)): 0.22
# Epoch [99/300], Step [400/600], d_loss: 0.6954, g_loss: 2.0391, D(x): 0.76, D(G(z)): 0.24
# Epoch [99/300], Step [600/600], d_loss: 0.7322, g_loss: 1.8077, D(x): 0.73, D(G(z)): 0.19
# Saving fake_images-0100.png
# Epoch [100/300], Step [200/600], d_loss: 0.7478, g_loss: 1.6450, D(x): 0.83, D(G(z)): 0.30
# Epoch [100/300], Step [400/600], d_loss: 0.6457, g_loss: 2.4336, D(x): 0.77, D(G(z)): 0.19
# Epoch [100/300], Step [600/600], d_loss: 0.9120, g_loss: 1.9961, D(x): 0.75, D(G(z)): 0.31
# Saving fake_images-0101.png
# Epoch [101/300], Step [200/600], d_loss: 1.1198, g_loss: 1.7061, D(x): 0.61, D(G(z)): 0.27
# Epoch [101/300], Step [400/600], d_loss: 0.8110, g_loss: 1.4713, D(x): 0.81, D(G(z)): 0.32
# Epoch [101/300], Step [600/600], d_loss: 0.7825, g_loss: 1.8961, D(x): 0.80, D(G(z)): 0.31
# Saving fake_images-0102.png
# Epoch [102/300], Step [200/600], d_loss: 0.8727, g_loss: 1.5011, D(x): 0.70, D(G(z)): 0.25
# Epoch [102/300], Step [400/600], d_loss: 0.6483, g_loss: 1.9480, D(x): 0.84, D(G(z)): 0.29
# Epoch [102/300], Step [600/600], d_loss: 0.8321, g_loss: 1.7189, D(x): 0.77, D(G(z)): 0.27
# Saving fake_images-0103.png
# Epoch [103/300], Step [200/600], d_loss: 0.7543, g_loss: 1.8415, D(x): 0.81, D(G(z)): 0.32
# Epoch [103/300], Step [400/600], d_loss: 0.8567, g_loss: 1.6773, D(x): 0.69, D(G(z)): 0.25
# Epoch [103/300], Step [600/600], d_loss: 0.7446, g_loss: 1.7782, D(x): 0.76, D(G(z)): 0.25
# Saving fake_images-0104.png
# Epoch [104/300], Step [200/600], d_loss: 0.8518, g_loss: 1.9884, D(x): 0.74, D(G(z)): 0.27
# Epoch [104/300], Step [400/600], d_loss: 0.6153, g_loss: 1.9443, D(x): 0.77, D(G(z)): 0.17
# Epoch [104/300], Step [600/600], d_loss: 0.7527, g_loss: 2.2917, D(x): 0.68, D(G(z)): 0.17
# Saving fake_images-0105.png
# Epoch [105/300], Step [200/600], d_loss: 0.6886, g_loss: 1.9232, D(x): 0.86, D(G(z)): 0.32
# Epoch [105/300], Step [400/600], d_loss: 0.6354, g_loss: 1.9140, D(x): 0.78, D(G(z)): 0.22
# Epoch [105/300], Step [600/600], d_loss: 0.9067, g_loss: 1.6967, D(x): 0.73, D(G(z)): 0.30
# Saving fake_images-0106.png
# Epoch [106/300], Step [200/600], d_loss: 1.0268, g_loss: 1.7872, D(x): 0.62, D(G(z)): 0.23
# Epoch [106/300], Step [400/600], d_loss: 0.8121, g_loss: 2.5420, D(x): 0.71, D(G(z)): 0.25
# Epoch [106/300], Step [600/600], d_loss: 0.6661, g_loss: 2.3013, D(x): 0.80, D(G(z)): 0.24
# Saving fake_images-0107.png
# Epoch [107/300], Step [200/600], d_loss: 0.9288, g_loss: 1.3183, D(x): 0.69, D(G(z)): 0.25
# Epoch [107/300], Step [400/600], d_loss: 0.7704, g_loss: 1.5952, D(x): 0.78, D(G(z)): 0.30
# Epoch [107/300], Step [600/600], d_loss: 0.8488, g_loss: 1.6671, D(x): 0.77, D(G(z)): 0.30
# Saving fake_images-0108.png
# Epoch [108/300], Step [200/600], d_loss: 0.6845, g_loss: 1.7543, D(x): 0.76, D(G(z)): 0.21
# Epoch [108/300], Step [400/600], d_loss: 0.7615, g_loss: 1.7186, D(x): 0.78, D(G(z)): 0.28
# Epoch [108/300], Step [600/600], d_loss: 0.6956, g_loss: 2.0262, D(x): 0.70, D(G(z)): 0.19
# Saving fake_images-0109.png
# Epoch [109/300], Step [200/600], d_loss: 1.1309, g_loss: 1.4554, D(x): 0.74, D(G(z)): 0.40
# Epoch [109/300], Step [400/600], d_loss: 0.6950, g_loss: 2.4865, D(x): 0.73, D(G(z)): 0.20
# Epoch [109/300], Step [600/600], d_loss: 0.7279, g_loss: 1.7469, D(x): 0.83, D(G(z)): 0.32
# Saving fake_images-0110.png
# Epoch [110/300], Step [200/600], d_loss: 0.9571, g_loss: 1.5285, D(x): 0.70, D(G(z)): 0.30
# Epoch [110/300], Step [400/600], d_loss: 0.7089, g_loss: 1.7408, D(x): 0.78, D(G(z)): 0.26
# Epoch [110/300], Step [600/600], d_loss: 0.8616, g_loss: 1.9382, D(x): 0.72, D(G(z)): 0.28
# Saving fake_images-0111.png
# Epoch [111/300], Step [200/600], d_loss: 0.7835, g_loss: 1.5578, D(x): 0.76, D(G(z)): 0.29
# Epoch [111/300], Step [400/600], d_loss: 0.7744, g_loss: 2.1179, D(x): 0.70, D(G(z)): 0.20
# Epoch [111/300], Step [600/600], d_loss: 0.5315, g_loss: 2.9575, D(x): 0.76, D(G(z)): 0.15
# Saving fake_images-0112.png
# Epoch [112/300], Step [200/600], d_loss: 0.8560, g_loss: 1.8087, D(x): 0.75, D(G(z)): 0.32
# Epoch [112/300], Step [400/600], d_loss: 0.5138, g_loss: 2.4742, D(x): 0.85, D(G(z)): 0.22
# Epoch [112/300], Step [600/600], d_loss: 1.0200, g_loss: 1.9860, D(x): 0.69, D(G(z)): 0.27
# Saving fake_images-0113.png
# Epoch [113/300], Step [200/600], d_loss: 0.8186, g_loss: 1.5825, D(x): 0.76, D(G(z)): 0.31
# Epoch [113/300], Step [400/600], d_loss: 0.9100, g_loss: 1.7018, D(x): 0.71, D(G(z)): 0.31
# Epoch [113/300], Step [600/600], d_loss: 0.7512, g_loss: 1.6449, D(x): 0.75, D(G(z)): 0.24
# Saving fake_images-0114.png
# Epoch [114/300], Step [200/600], d_loss: 0.7905, g_loss: 1.7785, D(x): 0.81, D(G(z)): 0.32
# Epoch [114/300], Step [400/600], d_loss: 0.9254, g_loss: 1.5648, D(x): 0.69, D(G(z)): 0.24
# Epoch [114/300], Step [600/600], d_loss: 0.6942, g_loss: 1.9419, D(x): 0.76, D(G(z)): 0.25
# Saving fake_images-0115.png
# Epoch [115/300], Step [200/600], d_loss: 1.0344, g_loss: 1.9114, D(x): 0.68, D(G(z)): 0.26
# Epoch [115/300], Step [400/600], d_loss: 0.8245, g_loss: 1.5794, D(x): 0.83, D(G(z)): 0.38
# Epoch [115/300], Step [600/600], d_loss: 0.8364, g_loss: 1.8687, D(x): 0.74, D(G(z)): 0.28
# Saving fake_images-0116.png
# Epoch [116/300], Step [200/600], d_loss: 0.9936, g_loss: 1.9277, D(x): 0.61, D(G(z)): 0.25
# Epoch [116/300], Step [400/600], d_loss: 0.6919, g_loss: 1.8045, D(x): 0.74, D(G(z)): 0.23
# Epoch [116/300], Step [600/600], d_loss: 0.6576, g_loss: 1.8414, D(x): 0.78, D(G(z)): 0.23
# Saving fake_images-0117.png
# Epoch [117/300], Step [200/600], d_loss: 0.9751, g_loss: 1.7173, D(x): 0.66, D(G(z)): 0.24
# Epoch [117/300], Step [400/600], d_loss: 0.9055, g_loss: 1.9743, D(x): 0.73, D(G(z)): 0.31
# Epoch [117/300], Step [600/600], d_loss: 0.8317, g_loss: 1.8650, D(x): 0.76, D(G(z)): 0.31
# Saving fake_images-0118.png
# Epoch [118/300], Step [200/600], d_loss: 0.8117, g_loss: 1.7305, D(x): 0.81, D(G(z)): 0.33
# Epoch [118/300], Step [400/600], d_loss: 1.0522, g_loss: 1.3269, D(x): 0.71, D(G(z)): 0.37
# Epoch [118/300], Step [600/600], d_loss: 1.0005, g_loss: 1.5012, D(x): 0.66, D(G(z)): 0.30
# Saving fake_images-0119.png
# Epoch [119/300], Step [200/600], d_loss: 0.6408, g_loss: 2.2925, D(x): 0.76, D(G(z)): 0.20
# Epoch [119/300], Step [400/600], d_loss: 1.0128, g_loss: 1.3057, D(x): 0.67, D(G(z)): 0.28
# Epoch [119/300], Step [600/600], d_loss: 0.6692, g_loss: 2.0792, D(x): 0.75, D(G(z)): 0.21
# Saving fake_images-0120.png
# Epoch [120/300], Step [200/600], d_loss: 0.7167, g_loss: 1.7230, D(x): 0.78, D(G(z)): 0.27
# Epoch [120/300], Step [400/600], d_loss: 1.1292, g_loss: 1.6916, D(x): 0.73, D(G(z)): 0.40
# Epoch [120/300], Step [600/600], d_loss: 0.9263, g_loss: 2.0276, D(x): 0.64, D(G(z)): 0.23
# Saving fake_images-0121.png
# Epoch [121/300], Step [200/600], d_loss: 0.9675, g_loss: 1.6923, D(x): 0.63, D(G(z)): 0.24
# Epoch [121/300], Step [400/600], d_loss: 0.9167, g_loss: 1.9832, D(x): 0.70, D(G(z)): 0.31
# Epoch [121/300], Step [600/600], d_loss: 0.8198, g_loss: 1.7325, D(x): 0.68, D(G(z)): 0.21
# Saving fake_images-0122.png
# Epoch [122/300], Step [200/600], d_loss: 1.0194, g_loss: 1.6586, D(x): 0.67, D(G(z)): 0.30
# Epoch [122/300], Step [400/600], d_loss: 0.8797, g_loss: 1.6742, D(x): 0.68, D(G(z)): 0.25
# Epoch [122/300], Step [600/600], d_loss: 0.8764, g_loss: 1.6739, D(x): 0.72, D(G(z)): 0.31
# Saving fake_images-0123.png
# Epoch [123/300], Step [200/600], d_loss: 0.7778, g_loss: 2.0031, D(x): 0.73, D(G(z)): 0.23
# Epoch [123/300], Step [400/600], d_loss: 0.8733, g_loss: 2.3196, D(x): 0.70, D(G(z)): 0.23
# Epoch [123/300], Step [600/600], d_loss: 0.9813, g_loss: 2.0503, D(x): 0.68, D(G(z)): 0.32
# Saving fake_images-0124.png
# Epoch [124/300], Step [200/600], d_loss: 1.0040, g_loss: 1.5839, D(x): 0.61, D(G(z)): 0.22
# Epoch [124/300], Step [400/600], d_loss: 1.1212, g_loss: 1.3705, D(x): 0.67, D(G(z)): 0.33
# Epoch [124/300], Step [600/600], d_loss: 0.9542, g_loss: 1.8377, D(x): 0.73, D(G(z)): 0.30
# Saving fake_images-0125.png
# Epoch [125/300], Step [200/600], d_loss: 1.0021, g_loss: 1.7073, D(x): 0.72, D(G(z)): 0.34
# Epoch [125/300], Step [400/600], d_loss: 0.8406, g_loss: 1.9187, D(x): 0.73, D(G(z)): 0.29
# Epoch [125/300], Step [600/600], d_loss: 1.0025, g_loss: 1.6553, D(x): 0.65, D(G(z)): 0.26
# Saving fake_images-0126.png
# Epoch [126/300], Step [200/600], d_loss: 1.0241, g_loss: 1.6016, D(x): 0.72, D(G(z)): 0.35
# Epoch [126/300], Step [400/600], d_loss: 0.9531, g_loss: 1.8339, D(x): 0.79, D(G(z)): 0.37
# Epoch [126/300], Step [600/600], d_loss: 0.7740, g_loss: 2.0725, D(x): 0.76, D(G(z)): 0.29
# Saving fake_images-0127.png
# Epoch [127/300], Step [200/600], d_loss: 1.1267, g_loss: 2.0689, D(x): 0.69, D(G(z)): 0.33
# Epoch [127/300], Step [400/600], d_loss: 0.9142, g_loss: 2.0708, D(x): 0.75, D(G(z)): 0.34
# Epoch [127/300], Step [600/600], d_loss: 0.9495, g_loss: 1.6749, D(x): 0.70, D(G(z)): 0.31
# Saving fake_images-0128.png
# Epoch [128/300], Step [200/600], d_loss: 0.8554, g_loss: 2.2297, D(x): 0.72, D(G(z)): 0.27
# Epoch [128/300], Step [400/600], d_loss: 0.8012, g_loss: 1.7906, D(x): 0.74, D(G(z)): 0.28
# Epoch [128/300], Step [600/600], d_loss: 0.9772, g_loss: 2.2010, D(x): 0.72, D(G(z)): 0.30
# Saving fake_images-0129.png
# Epoch [129/300], Step [200/600], d_loss: 0.7861, g_loss: 1.7276, D(x): 0.80, D(G(z)): 0.32
# Epoch [129/300], Step [400/600], d_loss: 0.9023, g_loss: 1.5315, D(x): 0.75, D(G(z)): 0.34
# Epoch [129/300], Step [600/600], d_loss: 0.8571, g_loss: 2.2060, D(x): 0.71, D(G(z)): 0.28
# Saving fake_images-0130.png
# Epoch [130/300], Step [200/600], d_loss: 0.8720, g_loss: 1.1884, D(x): 0.80, D(G(z)): 0.35
# Epoch [130/300], Step [400/600], d_loss: 0.8251, g_loss: 1.6492, D(x): 0.79, D(G(z)): 0.35
# Epoch [130/300], Step [600/600], d_loss: 0.9454, g_loss: 1.4807, D(x): 0.67, D(G(z)): 0.29
# Saving fake_images-0131.png
# Epoch [131/300], Step [200/600], d_loss: 0.8887, g_loss: 1.7770, D(x): 0.68, D(G(z)): 0.25
# Epoch [131/300], Step [400/600], d_loss: 0.6228, g_loss: 1.9617, D(x): 0.78, D(G(z)): 0.21
# Epoch [131/300], Step [600/600], d_loss: 0.8897, g_loss: 1.6224, D(x): 0.73, D(G(z)): 0.31
# Saving fake_images-0132.png
# Epoch [132/300], Step [200/600], d_loss: 0.8773, g_loss: 1.8211, D(x): 0.73, D(G(z)): 0.26
# Epoch [132/300], Step [400/600], d_loss: 0.7991, g_loss: 1.4878, D(x): 0.72, D(G(z)): 0.25
# Epoch [132/300], Step [600/600], d_loss: 0.8888, g_loss: 1.6950, D(x): 0.75, D(G(z)): 0.34
# Saving fake_images-0133.png
# Epoch [133/300], Step [200/600], d_loss: 0.7820, g_loss: 1.6117, D(x): 0.75, D(G(z)): 0.27
# Epoch [133/300], Step [400/600], d_loss: 0.9733, g_loss: 2.0399, D(x): 0.63, D(G(z)): 0.21
# Epoch [133/300], Step [600/600], d_loss: 0.7658, g_loss: 1.9654, D(x): 0.70, D(G(z)): 0.22
# Saving fake_images-0134.png
# Epoch [134/300], Step [200/600], d_loss: 0.9602, g_loss: 1.5775, D(x): 0.68, D(G(z)): 0.28
# Epoch [134/300], Step [400/600], d_loss: 0.9090, g_loss: 1.6062, D(x): 0.70, D(G(z)): 0.32
# Epoch [134/300], Step [600/600], d_loss: 0.9275, g_loss: 1.9967, D(x): 0.72, D(G(z)): 0.31
# Saving fake_images-0135.png
# Epoch [135/300], Step [200/600], d_loss: 1.0018, g_loss: 1.5245, D(x): 0.66, D(G(z)): 0.28
# Epoch [135/300], Step [400/600], d_loss: 0.8955, g_loss: 1.4988, D(x): 0.73, D(G(z)): 0.31
# Epoch [135/300], Step [600/600], d_loss: 0.9479, g_loss: 1.3012, D(x): 0.69, D(G(z)): 0.28
# Saving fake_images-0136.png
# Epoch [136/300], Step [200/600], d_loss: 1.0359, g_loss: 1.4788, D(x): 0.74, D(G(z)): 0.39
# Epoch [136/300], Step [400/600], d_loss: 0.8847, g_loss: 1.4647, D(x): 0.75, D(G(z)): 0.31
# Epoch [136/300], Step [600/600], d_loss: 0.8651, g_loss: 1.9270, D(x): 0.71, D(G(z)): 0.26
# Saving fake_images-0137.png
# Epoch [137/300], Step [200/600], d_loss: 0.8313, g_loss: 1.9058, D(x): 0.65, D(G(z)): 0.20
# Epoch [137/300], Step [400/600], d_loss: 0.9881, g_loss: 1.6457, D(x): 0.67, D(G(z)): 0.30
# Epoch [137/300], Step [600/600], d_loss: 1.0015, g_loss: 1.2684, D(x): 0.74, D(G(z)): 0.38
# Saving fake_images-0138.png
# Epoch [138/300], Step [200/600], d_loss: 0.9043, g_loss: 1.7130, D(x): 0.73, D(G(z)): 0.33
# Epoch [138/300], Step [400/600], d_loss: 0.9985, g_loss: 1.9269, D(x): 0.63, D(G(z)): 0.24
# Epoch [138/300], Step [600/600], d_loss: 0.8653, g_loss: 1.3022, D(x): 0.72, D(G(z)): 0.30
# Saving fake_images-0139.png
# Epoch [139/300], Step [200/600], d_loss: 0.9353, g_loss: 1.9458, D(x): 0.66, D(G(z)): 0.25
# Epoch [139/300], Step [400/600], d_loss: 0.7526, g_loss: 2.2465, D(x): 0.69, D(G(z)): 0.17
# Epoch [139/300], Step [600/600], d_loss: 0.8267, g_loss: 1.5574, D(x): 0.69, D(G(z)): 0.23
# Saving fake_images-0140.png
# Epoch [140/300], Step [200/600], d_loss: 1.1389, g_loss: 1.1898, D(x): 0.59, D(G(z)): 0.28
# Epoch [140/300], Step [400/600], d_loss: 0.8354, g_loss: 1.6789, D(x): 0.67, D(G(z)): 0.24
# Epoch [140/300], Step [600/600], d_loss: 0.8309, g_loss: 1.4439, D(x): 0.80, D(G(z)): 0.36
# Saving fake_images-0141.png
# Epoch [141/300], Step [200/600], d_loss: 0.8692, g_loss: 1.6563, D(x): 0.77, D(G(z)): 0.36
# Epoch [141/300], Step [400/600], d_loss: 0.9618, g_loss: 1.7640, D(x): 0.69, D(G(z)): 0.28
# Epoch [141/300], Step [600/600], d_loss: 0.8273, g_loss: 1.8460, D(x): 0.77, D(G(z)): 0.30
# Saving fake_images-0142.png
# Epoch [142/300], Step [200/600], d_loss: 1.1043, g_loss: 1.8178, D(x): 0.63, D(G(z)): 0.30
# Epoch [142/300], Step [400/600], d_loss: 0.7758, g_loss: 1.9250, D(x): 0.75, D(G(z)): 0.28
# Epoch [142/300], Step [600/600], d_loss: 0.8069, g_loss: 1.9601, D(x): 0.72, D(G(z)): 0.28
# Saving fake_images-0143.png
# Epoch [143/300], Step [200/600], d_loss: 0.8363, g_loss: 1.9893, D(x): 0.69, D(G(z)): 0.22
# Epoch [143/300], Step [400/600], d_loss: 0.8234, g_loss: 1.7610, D(x): 0.70, D(G(z)): 0.25
# Epoch [143/300], Step [600/600], d_loss: 0.7880, g_loss: 1.7090, D(x): 0.75, D(G(z)): 0.29
# Saving fake_images-0144.png
# Epoch [144/300], Step [200/600], d_loss: 0.8073, g_loss: 1.5691, D(x): 0.70, D(G(z)): 0.25
# Epoch [144/300], Step [400/600], d_loss: 1.0086, g_loss: 1.4424, D(x): 0.66, D(G(z)): 0.29
# Epoch [144/300], Step [600/600], d_loss: 0.8152, g_loss: 1.5600, D(x): 0.77, D(G(z)): 0.29
# Saving fake_images-0145.png
# Epoch [145/300], Step [200/600], d_loss: 0.9031, g_loss: 1.1845, D(x): 0.69, D(G(z)): 0.28
# Epoch [145/300], Step [400/600], d_loss: 0.8487, g_loss: 1.5666, D(x): 0.70, D(G(z)): 0.26
# Epoch [145/300], Step [600/600], d_loss: 0.9199, g_loss: 2.1465, D(x): 0.68, D(G(z)): 0.26
# Saving fake_images-0146.png
# Epoch [146/300], Step [200/600], d_loss: 0.8045, g_loss: 1.3959, D(x): 0.71, D(G(z)): 0.25
# Epoch [146/300], Step [400/600], d_loss: 0.5678, g_loss: 2.1244, D(x): 0.82, D(G(z)): 0.23
# Epoch [146/300], Step [600/600], d_loss: 0.8097, g_loss: 1.9882, D(x): 0.77, D(G(z)): 0.30
# Saving fake_images-0147.png
# Epoch [147/300], Step [200/600], d_loss: 0.8517, g_loss: 1.4635, D(x): 0.69, D(G(z)): 0.24
# Epoch [147/300], Step [400/600], d_loss: 0.9874, g_loss: 1.6361, D(x): 0.72, D(G(z)): 0.31
# Epoch [147/300], Step [600/600], d_loss: 0.9764, g_loss: 1.4269, D(x): 0.63, D(G(z)): 0.24
# Saving fake_images-0148.png
# Epoch [148/300], Step [200/600], d_loss: 0.9484, g_loss: 2.2064, D(x): 0.63, D(G(z)): 0.21
# Epoch [148/300], Step [400/600], d_loss: 1.0782, g_loss: 1.5899, D(x): 0.64, D(G(z)): 0.29
# Epoch [148/300], Step [600/600], d_loss: 0.8790, g_loss: 1.6845, D(x): 0.74, D(G(z)): 0.32
# Saving fake_images-0149.png
# Epoch [149/300], Step [200/600], d_loss: 0.8065, g_loss: 1.9015, D(x): 0.72, D(G(z)): 0.26
# Epoch [149/300], Step [400/600], d_loss: 0.9640, g_loss: 1.5692, D(x): 0.76, D(G(z)): 0.35
# Epoch [149/300], Step [600/600], d_loss: 0.9325, g_loss: 1.4207, D(x): 0.68, D(G(z)): 0.29
# Saving fake_images-0150.png
# Epoch [150/300], Step [200/600], d_loss: 1.0514, g_loss: 1.5985, D(x): 0.59, D(G(z)): 0.25
# Epoch [150/300], Step [400/600], d_loss: 0.9419, g_loss: 1.3067, D(x): 0.72, D(G(z)): 0.34
# Epoch [150/300], Step [600/600], d_loss: 0.8638, g_loss: 1.7470, D(x): 0.73, D(G(z)): 0.29
# Saving fake_images-0151.png
# Epoch [151/300], Step [200/600], d_loss: 0.9226, g_loss: 1.6149, D(x): 0.71, D(G(z)): 0.30
# Epoch [151/300], Step [400/600], d_loss: 1.0099, g_loss: 1.2949, D(x): 0.68, D(G(z)): 0.33
# Epoch [151/300], Step [600/600], d_loss: 0.7866, g_loss: 1.4067, D(x): 0.74, D(G(z)): 0.30
# Saving fake_images-0152.png
# Epoch [152/300], Step [200/600], d_loss: 0.6967, g_loss: 1.8596, D(x): 0.75, D(G(z)): 0.25
# Epoch [152/300], Step [400/600], d_loss: 0.8449, g_loss: 1.6144, D(x): 0.81, D(G(z)): 0.35
# Epoch [152/300], Step [600/600], d_loss: 0.8887, g_loss: 2.0548, D(x): 0.63, D(G(z)): 0.20
# Saving fake_images-0153.png
# Epoch [153/300], Step [200/600], d_loss: 0.9330, g_loss: 1.3862, D(x): 0.70, D(G(z)): 0.30
# Epoch [153/300], Step [400/600], d_loss: 0.9196, g_loss: 1.5344, D(x): 0.69, D(G(z)): 0.30
# Epoch [153/300], Step [600/600], d_loss: 0.7888, g_loss: 1.5432, D(x): 0.74, D(G(z)): 0.28
# Saving fake_images-0154.png
# Epoch [154/300], Step [200/600], d_loss: 1.1411, g_loss: 1.3318, D(x): 0.67, D(G(z)): 0.35
# Epoch [154/300], Step [400/600], d_loss: 0.7033, g_loss: 1.5358, D(x): 0.75, D(G(z)): 0.25
# Epoch [154/300], Step [600/600], d_loss: 0.7674, g_loss: 1.8501, D(x): 0.73, D(G(z)): 0.28
# Saving fake_images-0155.png
# Epoch [155/300], Step [200/600], d_loss: 0.9962, g_loss: 1.4930, D(x): 0.69, D(G(z)): 0.31
# Epoch [155/300], Step [400/600], d_loss: 0.8970, g_loss: 1.5297, D(x): 0.68, D(G(z)): 0.27
# Epoch [155/300], Step [600/600], d_loss: 0.8203, g_loss: 1.6882, D(x): 0.81, D(G(z)): 0.35
# Saving fake_images-0156.png
# Epoch [156/300], Step [200/600], d_loss: 0.8215, g_loss: 1.8887, D(x): 0.71, D(G(z)): 0.29
# Epoch [156/300], Step [400/600], d_loss: 0.9080, g_loss: 2.1150, D(x): 0.67, D(G(z)): 0.23
# Epoch [156/300], Step [600/600], d_loss: 1.0049, g_loss: 1.5321, D(x): 0.74, D(G(z)): 0.38
# Saving fake_images-0157.png
# Epoch [157/300], Step [200/600], d_loss: 0.8082, g_loss: 1.6370, D(x): 0.76, D(G(z)): 0.32
# Epoch [157/300], Step [400/600], d_loss: 1.0349, g_loss: 1.4402, D(x): 0.65, D(G(z)): 0.27
# Epoch [157/300], Step [600/600], d_loss: 0.8054, g_loss: 1.4012, D(x): 0.74, D(G(z)): 0.30
# Saving fake_images-0158.png
# Epoch [158/300], Step [200/600], d_loss: 1.0684, g_loss: 1.6024, D(x): 0.63, D(G(z)): 0.28
# Epoch [158/300], Step [400/600], d_loss: 0.9791, g_loss: 1.7280, D(x): 0.76, D(G(z)): 0.40
# Epoch [158/300], Step [600/600], d_loss: 1.0779, g_loss: 1.6561, D(x): 0.64, D(G(z)): 0.30
# Saving fake_images-0159.png
# Epoch [159/300], Step [200/600], d_loss: 0.9244, g_loss: 1.5846, D(x): 0.74, D(G(z)): 0.36
# Epoch [159/300], Step [400/600], d_loss: 0.8899, g_loss: 1.3077, D(x): 0.69, D(G(z)): 0.28
# Epoch [159/300], Step [600/600], d_loss: 0.9321, g_loss: 1.4752, D(x): 0.74, D(G(z)): 0.36
# Saving fake_images-0160.png
# Epoch [160/300], Step [200/600], d_loss: 0.9665, g_loss: 1.5952, D(x): 0.69, D(G(z)): 0.28
# ...
# Epoch [247/300], Step [400/600], d_loss: 1.0622, g_loss: 1.3199, D(x): 0.61, D(G(z)): 0.27
# Epoch [247/300], Step [600/600], d_loss: 0.8775, g_loss: 1.7173, D(x): 0.72, D(G(z)): 0.29
# Saving fake_images-0248.png
# Epoch [248/300], Step [200/600], d_loss: 0.7839, g_loss: 1.5194, D(x): 0.75, D(G(z)): 0.29
# Epoch [248/300], Step [400/600], d_loss: 0.9476, g_loss: 1.5893, D(x): 0.67, D(G(z)): 0.31
# Epoch [248/300], Step [600/600], d_loss: 0.9273, g_loss: 1.6091, D(x): 0.68, D(G(z)): 0.29
# Saving fake_images-0249.png
# Epoch [249/300], Step [200/600], d_loss: 0.9328, g_loss: 1.8232, D(x): 0.70, D(G(z)): 0.31
# Epoch [249/300], Step [400/600], d_loss: 0.9323, g_loss: 1.6076, D(x): 0.71, D(G(z)): 0.35
# Epoch [249/300], Step [600/600], d_loss: 0.7986, g_loss: 1.7207, D(x): 0.69, D(G(z)): 0.24
# Saving fake_images-0250.png
# Epoch [250/300], Step [200/600], d_loss: 0.9367, g_loss: 1.7726, D(x): 0.68, D(G(z)): 0.29
# Epoch [250/300], Step [400/600], d_loss: 0.8153, g_loss: 1.3305, D(x): 0.70, D(G(z)): 0.27
# Epoch [250/300], Step [600/600], d_loss: 1.0763, g_loss: 1.3398, D(x): 0.73, D(G(z)): 0.39
# Saving fake_images-0251.png
# Epoch [251/300], Step [200/600], d_loss: 0.9092, g_loss: 1.5258, D(x): 0.75, D(G(z)): 0.35
# Epoch [251/300], Step [400/600], d_loss: 0.9417, g_loss: 1.5053, D(x): 0.71, D(G(z)): 0.36
# Epoch [251/300], Step [600/600], d_loss: 0.9049, g_loss: 2.0418, D(x): 0.68, D(G(z)): 0.27
# Saving fake_images-0252.png
# Epoch [252/300], Step [200/600], d_loss: 1.1213, g_loss: 1.1489, D(x): 0.70, D(G(z)): 0.40
# Epoch [252/300], Step [400/600], d_loss: 0.8531, g_loss: 1.4049, D(x): 0.78, D(G(z)): 0.37
# Epoch [252/300], Step [600/600], d_loss: 0.9292, g_loss: 1.2819, D(x): 0.72, D(G(z)): 0.33
# Saving fake_images-0253.png
# Epoch [253/300], Step [200/600], d_loss: 0.8601, g_loss: 1.6366, D(x): 0.67, D(G(z)): 0.25
# Epoch [253/300], Step [400/600], d_loss: 0.8732, g_loss: 1.5897, D(x): 0.67, D(G(z)): 0.25
# Epoch [253/300], Step [600/600], d_loss: 0.8258, g_loss: 1.4409, D(x): 0.70, D(G(z)): 0.27
# Saving fake_images-0254.png
# Epoch [254/300], Step [200/600], d_loss: 1.0863, g_loss: 1.4362, D(x): 0.69, D(G(z)): 0.39
# Epoch [254/300], Step [400/600], d_loss: 0.9800, g_loss: 1.6501, D(x): 0.65, D(G(z)): 0.27
# Epoch [254/300], Step [600/600], d_loss: 0.9816, g_loss: 1.3090, D(x): 0.69, D(G(z)): 0.33
# Saving fake_images-0255.png
# Epoch [255/300], Step [200/600], d_loss: 0.8290, g_loss: 1.7319, D(x): 0.69, D(G(z)): 0.27
# Epoch [255/300], Step [400/600], d_loss: 0.8402, g_loss: 1.6256, D(x): 0.72, D(G(z)): 0.28
# Epoch [255/300], Step [600/600], d_loss: 1.1828, g_loss: 1.4820, D(x): 0.62, D(G(z)): 0.35
# Saving fake_images-0256.png
# Epoch [256/300], Step [200/600], d_loss: 0.9068, g_loss: 1.2559, D(x): 0.68, D(G(z)): 0.30
# Epoch [256/300], Step [400/600], d_loss: 1.0916, g_loss: 1.5642, D(x): 0.63, D(G(z)): 0.29
# Epoch [256/300], Step [600/600], d_loss: 0.8718, g_loss: 2.0056, D(x): 0.76, D(G(z)): 0.34
# Saving fake_images-0257.png
# Epoch [257/300], Step [200/600], d_loss: 0.9258, g_loss: 1.3417, D(x): 0.71, D(G(z)): 0.32
# Epoch [257/300], Step [400/600], d_loss: 0.8642, g_loss: 1.8173, D(x): 0.70, D(G(z)): 0.30
# Epoch [257/300], Step [600/600], d_loss: 0.9328, g_loss: 1.3637, D(x): 0.71, D(G(z)): 0.32
# Saving fake_images-0258.png
# Epoch [258/300], Step [200/600], d_loss: 0.8793, g_loss: 1.6682, D(x): 0.74, D(G(z)): 0.32
# Epoch [258/300], Step [400/600], d_loss: 0.8919, g_loss: 1.4427, D(x): 0.65, D(G(z)): 0.24
# Epoch [258/300], Step [600/600], d_loss: 0.8910, g_loss: 1.4047, D(x): 0.73, D(G(z)): 0.33
# Saving fake_images-0259.png
# Epoch [259/300], Step [200/600], d_loss: 0.8561, g_loss: 1.5730, D(x): 0.71, D(G(z)): 0.29
# Epoch [259/300], Step [400/600], d_loss: 0.8780, g_loss: 1.6083, D(x): 0.68, D(G(z)): 0.27
# Epoch [259/300], Step [600/600], d_loss: 0.8880, g_loss: 1.4671, D(x): 0.70, D(G(z)): 0.29
# Saving fake_images-0260.png
# Epoch [260/300], Step [200/600], d_loss: 0.8693, g_loss: 1.6284, D(x): 0.71, D(G(z)): 0.31
# Epoch [260/300], Step [400/600], d_loss: 0.9862, g_loss: 1.4144, D(x): 0.64, D(G(z)): 0.27
# Epoch [260/300], Step [600/600], d_loss: 0.8978, g_loss: 1.5299, D(x): 0.64, D(G(z)): 0.26
# Saving fake_images-0261.png
# Epoch [261/300], Step [200/600], d_loss: 0.8464, g_loss: 1.7402, D(x): 0.67, D(G(z)): 0.24
# Epoch [261/300], Step [400/600], d_loss: 0.9065, g_loss: 1.6501, D(x): 0.68, D(G(z)): 0.27
# Epoch [261/300], Step [600/600], d_loss: 0.9088, g_loss: 1.4605, D(x): 0.75, D(G(z)): 0.34
# Saving fake_images-0262.png
# Epoch [262/300], Step [200/600], d_loss: 0.9634, g_loss: 1.3310, D(x): 0.70, D(G(z)): 0.31
# Epoch [262/300], Step [400/600], d_loss: 0.8900, g_loss: 1.4657, D(x): 0.70, D(G(z)): 0.32
# Epoch [262/300], Step [600/600], d_loss: 0.9504, g_loss: 1.2350, D(x): 0.73, D(G(z)): 0.37
# Saving fake_images-0263.png
# Epoch [263/300], Step [200/600], d_loss: 0.8423, g_loss: 1.6225, D(x): 0.75, D(G(z)): 0.31
# Epoch [263/300], Step [400/600], d_loss: 0.7104, g_loss: 1.5632, D(x): 0.75, D(G(z)): 0.27
# Epoch [263/300], Step [600/600], d_loss: 1.0202, g_loss: 1.5444, D(x): 0.69, D(G(z)): 0.37
# Saving fake_images-0264.png
# Epoch [264/300], Step [200/600], d_loss: 1.0426, g_loss: 1.2801, D(x): 0.66, D(G(z)): 0.33
# Epoch [264/300], Step [400/600], d_loss: 0.8517, g_loss: 1.3949, D(x): 0.69, D(G(z)): 0.25
# Epoch [264/300], Step [600/600], d_loss: 1.0404, g_loss: 1.2547, D(x): 0.69, D(G(z)): 0.38
# Saving fake_images-0265.png
# Epoch [265/300], Step [200/600], d_loss: 0.8442, g_loss: 1.5647, D(x): 0.75, D(G(z)): 0.32
# Epoch [265/300], Step [400/600], d_loss: 0.9716, g_loss: 1.5346, D(x): 0.65, D(G(z)): 0.26
# Epoch [265/300], Step [600/600], d_loss: 0.9083, g_loss: 1.5363, D(x): 0.76, D(G(z)): 0.35
# Saving fake_images-0266.png
# Epoch [266/300], Step [200/600], d_loss: 0.9742, g_loss: 1.7456, D(x): 0.65, D(G(z)): 0.28
# Epoch [266/300], Step [400/600], d_loss: 0.8559, g_loss: 1.5391, D(x): 0.73, D(G(z)): 0.30
# Epoch [266/300], Step [600/600], d_loss: 0.9837, g_loss: 1.3302, D(x): 0.68, D(G(z)): 0.33
# Saving fake_images-0267.png
# Epoch [267/300], Step [200/600], d_loss: 0.9989, g_loss: 1.4662, D(x): 0.72, D(G(z)): 0.35
# Epoch [267/300], Step [400/600], d_loss: 0.6891, g_loss: 1.9987, D(x): 0.72, D(G(z)): 0.21
# Epoch [267/300], Step [600/600], d_loss: 0.9101, g_loss: 1.4375, D(x): 0.71, D(G(z)): 0.33
# Saving fake_images-0268.png
# Epoch [268/300], Step [200/600], d_loss: 0.9125, g_loss: 1.1668, D(x): 0.71, D(G(z)): 0.35
# Epoch [268/300], Step [400/600], d_loss: 1.0645, g_loss: 1.3614, D(x): 0.63, D(G(z)): 0.28
# Epoch [268/300], Step [600/600], d_loss: 1.0013, g_loss: 1.2903, D(x): 0.71, D(G(z)): 0.38
# Saving fake_images-0269.png
# Epoch [269/300], Step [200/600], d_loss: 1.0746, g_loss: 1.3203, D(x): 0.65, D(G(z)): 0.34
# Epoch [269/300], Step [400/600], d_loss: 0.9937, g_loss: 1.4505, D(x): 0.67, D(G(z)): 0.32
# Epoch [269/300], Step [600/600], d_loss: 0.8549, g_loss: 1.2902, D(x): 0.78, D(G(z)): 0.34
# Saving fake_images-0270.png
# Epoch [270/300], Step [200/600], d_loss: 0.8059, g_loss: 1.4318, D(x): 0.75, D(G(z)): 0.29
# Epoch [270/300], Step [400/600], d_loss: 1.0211, g_loss: 1.4207, D(x): 0.67, D(G(z)): 0.34
# Epoch [270/300], Step [600/600], d_loss: 0.9363, g_loss: 1.7077, D(x): 0.62, D(G(z)): 0.24
# Saving fake_images-0271.png
# Epoch [271/300], Step [200/600], d_loss: 0.9747, g_loss: 1.4486, D(x): 0.63, D(G(z)): 0.26
# Epoch [271/300], Step [400/600], d_loss: 0.8681, g_loss: 1.5290, D(x): 0.80, D(G(z)): 0.39
# Epoch [271/300], Step [600/600], d_loss: 0.9205, g_loss: 1.4461, D(x): 0.72, D(G(z)): 0.34
# Saving fake_images-0272.png
# Epoch [272/300], Step [200/600], d_loss: 1.1277, g_loss: 1.3416, D(x): 0.57, D(G(z)): 0.23
# Epoch [272/300], Step [400/600], d_loss: 0.8154, g_loss: 1.2248, D(x): 0.76, D(G(z)): 0.30
# Epoch [272/300], Step [600/600], d_loss: 0.9143, g_loss: 1.6184, D(x): 0.69, D(G(z)): 0.30
# Saving fake_images-0273.png
# Epoch [273/300], Step [200/600], d_loss: 0.8386, g_loss: 1.6744, D(x): 0.68, D(G(z)): 0.24
# Epoch [273/300], Step [400/600], d_loss: 0.9302, g_loss: 1.9088, D(x): 0.73, D(G(z)): 0.34
# Epoch [273/300], Step [600/600], d_loss: 0.9890, g_loss: 1.2777, D(x): 0.72, D(G(z)): 0.36
# Saving fake_images-0274.png
# Epoch [274/300], Step [200/600], d_loss: 0.9896, g_loss: 1.4537, D(x): 0.68, D(G(z)): 0.33
# Epoch [274/300], Step [400/600], d_loss: 0.9883, g_loss: 1.5580, D(x): 0.76, D(G(z)): 0.42
# Epoch [274/300], Step [600/600], d_loss: 1.0156, g_loss: 1.2074, D(x): 0.73, D(G(z)): 0.39
# Saving fake_images-0275.png
# Epoch [275/300], Step [200/600], d_loss: 0.9365, g_loss: 1.1736, D(x): 0.66, D(G(z)): 0.28
# Epoch [275/300], Step [400/600], d_loss: 0.8296, g_loss: 1.7145, D(x): 0.74, D(G(z)): 0.31
# Epoch [275/300], Step [600/600], d_loss: 1.0229, g_loss: 1.6192, D(x): 0.65, D(G(z)): 0.29
# Saving fake_images-0276.png
# Epoch [276/300], Step [200/600], d_loss: 0.9677, g_loss: 1.8252, D(x): 0.68, D(G(z)): 0.28
# Epoch [276/300], Step [400/600], d_loss: 0.8590, g_loss: 1.3585, D(x): 0.72, D(G(z)): 0.29
# Epoch [276/300], Step [600/600], d_loss: 0.8776, g_loss: 1.3083, D(x): 0.70, D(G(z)): 0.30
# Saving fake_images-0277.png
# Epoch [277/300], Step [200/600], d_loss: 0.9094, g_loss: 1.5918, D(x): 0.80, D(G(z)): 0.37
# Epoch [277/300], Step [400/600], d_loss: 0.8186, g_loss: 1.5692, D(x): 0.77, D(G(z)): 0.32
# Epoch [277/300], Step [600/600], d_loss: 0.9544, g_loss: 1.9061, D(x): 0.67, D(G(z)): 0.26
# Saving fake_images-0278.png
# Epoch [278/300], Step [200/600], d_loss: 1.0288, g_loss: 1.4945, D(x): 0.73, D(G(z)): 0.37
# Epoch [278/300], Step [400/600], d_loss: 0.8972, g_loss: 1.5655, D(x): 0.71, D(G(z)): 0.33
# Epoch [278/300], Step [600/600], d_loss: 0.8752, g_loss: 1.8369, D(x): 0.69, D(G(z)): 0.24
# Saving fake_images-0279.png
# Epoch [279/300], Step [200/600], d_loss: 0.7578, g_loss: 1.4400, D(x): 0.72, D(G(z)): 0.25
# Epoch [279/300], Step [400/600], d_loss: 0.9014, g_loss: 1.7786, D(x): 0.68, D(G(z)): 0.28
# Epoch [279/300], Step [600/600], d_loss: 0.8599, g_loss: 1.7610, D(x): 0.66, D(G(z)): 0.24
# Saving fake_images-0280.png
# Epoch [280/300], Step [200/600], d_loss: 0.8063, g_loss: 1.4339, D(x): 0.77, D(G(z)): 0.32
# Epoch [280/300], Step [400/600], d_loss: 0.8970, g_loss: 1.3430, D(x): 0.70, D(G(z)): 0.31
# Epoch [280/300], Step [600/600], d_loss: 0.9986, g_loss: 1.4364, D(x): 0.71, D(G(z)): 0.37
# Saving fake_images-0281.png
# Epoch [281/300], Step [200/600], d_loss: 0.8780, g_loss: 1.2605, D(x): 0.78, D(G(z)): 0.37
# Epoch [281/300], Step [400/600], d_loss: 0.8781, g_loss: 1.4182, D(x): 0.72, D(G(z)): 0.31
# Epoch [281/300], Step [600/600], d_loss: 0.7620, g_loss: 1.9680, D(x): 0.73, D(G(z)): 0.24
# Saving fake_images-0282.png
# Epoch [282/300], Step [200/600], d_loss: 0.9775, g_loss: 1.7736, D(x): 0.66, D(G(z)): 0.28
# Epoch [282/300], Step [400/600], d_loss: 0.8197, g_loss: 1.5815, D(x): 0.72, D(G(z)): 0.27
# Epoch [282/300], Step [600/600], d_loss: 0.9049, g_loss: 1.5190, D(x): 0.68, D(G(z)): 0.26
# Saving fake_images-0283.png
# Epoch [283/300], Step [200/600], d_loss: 0.9783, g_loss: 1.3714, D(x): 0.66, D(G(z)): 0.31
# Epoch [283/300], Step [400/600], d_loss: 0.9817, g_loss: 1.3937, D(x): 0.68, D(G(z)): 0.31
# Epoch [283/300], Step [600/600], d_loss: 1.0362, g_loss: 1.6691, D(x): 0.64, D(G(z)): 0.29
# Saving fake_images-0284.png
# Epoch [284/300], Step [200/600], d_loss: 0.8227, g_loss: 1.3360, D(x): 0.65, D(G(z)): 0.20
# Epoch [284/300], Step [400/600], d_loss: 0.8545, g_loss: 2.1273, D(x): 0.71, D(G(z)): 0.29
# Epoch [284/300], Step [600/600], d_loss: 0.9418, g_loss: 1.4314, D(x): 0.66, D(G(z)): 0.29
# Saving fake_images-0285.png
# Epoch [285/300], Step [200/600], d_loss: 0.8207, g_loss: 1.5123, D(x): 0.73, D(G(z)): 0.30
# Epoch [285/300], Step [400/600], d_loss: 0.8637, g_loss: 1.2442, D(x): 0.71, D(G(z)): 0.31
# Epoch [285/300], Step [600/600], d_loss: 0.8294, g_loss: 1.6814, D(x): 0.73, D(G(z)): 0.30
# Saving fake_images-0286.png
# Epoch [286/300], Step [200/600], d_loss: 0.9591, g_loss: 1.8544, D(x): 0.59, D(G(z)): 0.20
# Epoch [286/300], Step [400/600], d_loss: 0.8676, g_loss: 1.5783, D(x): 0.77, D(G(z)): 0.35
# Epoch [286/300], Step [600/600], d_loss: 1.0627, g_loss: 1.5412, D(x): 0.66, D(G(z)): 0.33
# Saving fake_images-0287.png
# Epoch [287/300], Step [200/600], d_loss: 0.9544, g_loss: 1.3702, D(x): 0.71, D(G(z)): 0.34
# Epoch [287/300], Step [400/600], d_loss: 1.0050, g_loss: 1.2434, D(x): 0.73, D(G(z)): 0.36
# Epoch [287/300], Step [600/600], d_loss: 0.9521, g_loss: 1.3032, D(x): 0.70, D(G(z)): 0.34
# Saving fake_images-0288.png
# Epoch [288/300], Step [200/600], d_loss: 0.9511, g_loss: 1.4995, D(x): 0.68, D(G(z)): 0.31
# Epoch [288/300], Step [400/600], d_loss: 0.8894, g_loss: 1.3255, D(x): 0.68, D(G(z)): 0.28
# Epoch [288/300], Step [600/600], d_loss: 0.9926, g_loss: 1.6113, D(x): 0.64, D(G(z)): 0.28
# Saving fake_images-0289.png
# Epoch [289/300], Step [200/600], d_loss: 0.9395, g_loss: 1.8238, D(x): 0.59, D(G(z)): 0.19
# Epoch [289/300], Step [400/600], d_loss: 0.7915, g_loss: 1.3152, D(x): 0.78, D(G(z)): 0.32
# Epoch [289/300], Step [600/600], d_loss: 0.8415, g_loss: 1.6857, D(x): 0.73, D(G(z)): 0.28
# Saving fake_images-0290.png
# Epoch [290/300], Step [200/600], d_loss: 0.9541, g_loss: 1.4124, D(x): 0.62, D(G(z)): 0.23
# Epoch [290/300], Step [400/600], d_loss: 0.9530, g_loss: 1.5491, D(x): 0.62, D(G(z)): 0.22
# Epoch [290/300], Step [600/600], d_loss: 0.8886, g_loss: 1.7322, D(x): 0.64, D(G(z)): 0.24
# Saving fake_images-0291.png
# Epoch [291/300], Step [200/600], d_loss: 0.8810, g_loss: 1.6349, D(x): 0.63, D(G(z)): 0.22
# Epoch [291/300], Step [400/600], d_loss: 0.9639, g_loss: 1.5260, D(x): 0.65, D(G(z)): 0.30
# Epoch [291/300], Step [600/600], d_loss: 0.9276, g_loss: 1.6534, D(x): 0.69, D(G(z)): 0.31
# Saving fake_images-0292.png
# Epoch [292/300], Step [200/600], d_loss: 0.9859, g_loss: 1.4472, D(x): 0.68, D(G(z)): 0.30
# Epoch [292/300], Step [400/600], d_loss: 0.8866, g_loss: 1.6645, D(x): 0.68, D(G(z)): 0.27
# Epoch [292/300], Step [600/600], d_loss: 0.8716, g_loss: 1.7864, D(x): 0.77, D(G(z)): 0.31
# Saving fake_images-0293.png
# Epoch [293/300], Step [200/600], d_loss: 1.0339, g_loss: 1.5448, D(x): 0.69, D(G(z)): 0.36
# Epoch [293/300], Step [400/600], d_loss: 0.9274, g_loss: 1.8161, D(x): 0.67, D(G(z)): 0.26
# Epoch [293/300], Step [600/600], d_loss: 0.9876, g_loss: 1.7889, D(x): 0.73, D(G(z)): 0.37
# Saving fake_images-0294.png
# Epoch [294/300], Step [200/600], d_loss: 0.9845, g_loss: 1.6518, D(x): 0.69, D(G(z)): 0.31
# Epoch [294/300], Step [400/600], d_loss: 0.9144, g_loss: 1.7746, D(x): 0.75, D(G(z)): 0.33
# Epoch [294/300], Step [600/600], d_loss: 0.8930, g_loss: 1.5561, D(x): 0.66, D(G(z)): 0.27
# Saving fake_images-0295.png
# Epoch [295/300], Step [200/600], d_loss: 1.0526, g_loss: 1.1897, D(x): 0.72, D(G(z)): 0.37
# Epoch [295/300], Step [400/600], d_loss: 0.9728, g_loss: 1.7728, D(x): 0.65, D(G(z)): 0.29
# Epoch [295/300], Step [600/600], d_loss: 0.9457, g_loss: 1.4067, D(x): 0.72, D(G(z)): 0.35
# Saving fake_images-0296.png
# Epoch [296/300], Step [200/600], d_loss: 0.9580, g_loss: 1.3490, D(x): 0.68, D(G(z)): 0.33
# Epoch [296/300], Step [400/600], d_loss: 0.9582, g_loss: 1.6864, D(x): 0.67, D(G(z)): 0.31
# Epoch [296/300], Step [600/600], d_loss: 0.8401, g_loss: 1.5474, D(x): 0.75, D(G(z)): 0.33
# Saving fake_images-0297.png
# Epoch [297/300], Step [200/600], d_loss: 0.8385, g_loss: 1.2850, D(x): 0.75, D(G(z)): 0.34
# Epoch [297/300], Step [400/600], d_loss: 0.8504, g_loss: 1.6846, D(x): 0.70, D(G(z)): 0.29
# Epoch [297/300], Step [600/600], d_loss: 1.0151, g_loss: 1.3115, D(x): 0.65, D(G(z)): 0.33
# Saving fake_images-0298.png
# Epoch [298/300], Step [200/600], d_loss: 0.7353, g_loss: 1.3423, D(x): 0.71, D(G(z)): 0.23
# Epoch [298/300], Step [400/600], d_loss: 0.8651, g_loss: 1.3614, D(x): 0.69, D(G(z)): 0.28
# Epoch [298/300], Step [600/600], d_loss: 0.9508, g_loss: 1.3617, D(x): 0.70, D(G(z)): 0.34
# Saving fake_images-0299.png
# Epoch [299/300], Step [200/600], d_loss: 0.9207, g_loss: 1.5902, D(x): 0.63, D(G(z)): 0.22
# Epoch [299/300], Step [400/600], d_loss: 1.0510, g_loss: 1.3734, D(x): 0.70, D(G(z)): 0.36
# Epoch [299/300], Step [600/600], d_loss: 0.9670, g_loss: 1.4726, D(x): 0.75, D(G(z)): 0.38
# Saving fake_images-0300.png
# CPU times: user 35min 21s, sys: 2min 59s, total: 38min 20s
# Wall time: 39min 36s

# %%
# Save the model checkpoints 
torch.save(G.state_dict(), 'G.ckpt')
torch.save(D.state_dict(), 'D.ckpt')

# %% [markdown]
# #### Let's observe how the generated images look like, after the 10th, 50th, 100th and 300th epochs of training.
# #### Hopefully, we'll be able to see the improvement of the generator.

# %%
Image('../data/samples/fake_images-0010.png')

# %%
Image('../data/samples/fake_images-0050.png')

# %%
Image('../data/samples/fake_images-0100.png')

# %%
Image('../data/samples/fake_images-0300.png')

# %% [markdown]
# #### Let's take a look at the loss this time, for a more numerical analysis.

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %% [markdown]
# #### For the score output by the discriminator, we are hoping both scores converge to near 0.5 values.
# #### What this means is that for real and fake images, the discriminator can only output 0.5 probability, which literally means it is equivalent to pure guessing.

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');

# %% [markdown]
# #### Even with such a simple model, without any convolutional layers of any sort, we were able to come up with a pretty decent model.
# #### Visually, it seems to be able to generate pretty convincing pictures of the MNIST data and the losses and scores back up the observation.
# #### You can try to alter the model architecture to make it more complex which can possibly come up with more realistic data!
